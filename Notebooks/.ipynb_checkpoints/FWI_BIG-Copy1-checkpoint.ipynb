# %%
#Save the below parameters to output.txt file
# %logstart -o -r -t -q output.txt rotate

# %%
# General info
# using Adam Optimization
# Shuffling sources every epoch
# SCHUSTER's MARMOUSI MODEL

# General parameters
GPU=2     # which GPU to use
plot=True # Plot Intermediate results
sigma=5.0   # Initial model smoothness  

# Inversion parameters
num_batches = 2
num_epochs = 5000

#gamma = 300  # Does not apply, Adam uses lr (learning rate) instead of gamma
# Adam learning rate
lr = 4

# Modeling parameters
freq = 12
dx = 10
dt = 0.001
nt = 4001
num_shots = 18
num_receivers_per_shot = 200

# receiver_spacing = # computed below from ny,dx and num_receivers_per_shot

# Close the ouput.txt file with saved parameters
# %logstop

# %%
# Need to restart runtime before this step
import time
import torch
import numpy as np
import scipy.ndimage
import scipy.io
import matplotlib.pyplot as plt
import deepwave
import os
import csv
from sklearn.feature_extraction import image
from skimage.transform import resize
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
NX = 500;
NY = 174;
f = open("AllModels/marmousi_II_marine.vp")
data_type = np.dtype ('float32').newbyteorder ('<')
mod_true = np.fromfile (f, dtype=data_type)
mod_true = mod_true.reshape(NX,NY)
mod_true = np.transpose(mod_true)
#mod_true = np.flipud(mod_true)
plt.figure(figsize=(12,8))
fmarmousi = mod_true[:,25:475]
mat = resize(fmarmousi,(151,200))
plt.imshow(mat,'RdBu_r')
plt.colorbar()

# %%
plt.imshow(mat)

# %%
ny = np.size(mat,1);
nz = np.size(mat,0);
#RB compute true model mean value and width for future model normalization
max1=np.max(mat)
min1=np.min(mat)
med=(max1+min1)/2.
wid=(max1-min1)/2.

print('vmin=',min1,'vmax=',max1,'vmed=',med,'vwidth=',wid)
# Out:
# vmin= 1500.0 vmax= 4766.604 vmed= 3133.302001953125 vwidth= 1633.302001953125

# %%
#RB Open file to write results
f = open('marmsm_Mod8_log.txt','a+')
writer = csv.writer(f)

#RB Write header
fields=['Epoch','it','loss.item','epoch_loss','it_lap','epoch_lap']
writer.writerow(fields)
f.flush()
os.fsync(f)

# %%
# Specify which GPU to use (in multi GPU machines)
torch.cuda.set_device(GPU)  #RB Necessary if device <> 0
GPU_string='cuda:'+str(GPU)
device = torch.device(GPU_string)

# %%
# Set parameters
num_dims = 2
#num_shots = 32
num_sources_per_shot = 1
#num_receivers_per_shot = 200

#RB source_spacing = 25.0
#RB receiver_spacing = 10.0
source_spacing = ny * dx / num_shots
receiver_spacing = ny * dx / num_receivers_per_shot
#receiver_spacing = 8.

print('ny=',ny,'nz=',nz,'nt=',nt,'dx=',dx,'freq=',freq)
print('shots=',num_shots,'recs/shot=',num_receivers_per_shot, \
      'ds=',source_spacing,'dr=',receiver_spacing)
# Out:
# ny= 200 nz= 151 nt= 4001 dx= 10 freq= 12
# shots= 18 recs/shot= 200 ds= 111.11111111111111 dr= 10.0

# %%
# Create arrays containing the source and receiver locations
# x_s: Source locations [num_shots, num_sources_per_shot, num_dimensions]
# x_r: Receiver locations [num_shots, num_receivers_per_shot, num_dimensions]
x_s = torch.zeros(num_shots, num_sources_per_shot, num_dims)
x_s[:, 0, 1] = torch.linspace(0,(ny-1)*dx,num_shots)
#x_s[:, 0, 0] = 100. #RB Set source depth

x_r = torch.zeros(num_shots, num_receivers_per_shot, num_dims)
x_r[0, :, 1] = torch.arange(num_receivers_per_shot).float() * receiver_spacing
x_r[:, :, 1] = x_r[0, :, 1].repeat(num_shots, 1)

#RB Shuffle shot coordinates
###idx = torch.randperm(num_shots)
###x_s = x_s.view(-1,2)[idx].view(x_s.size())

#RB Set Receiver depth
#x_r[0, :, 0] = 100.
#x_r[:, :, 0] = x_r[0, :, 0].repeat(num_shots, 1)

# Create true source amplitudes [nt, num_shots, num_sources_per_shot]
# I use Deepwave's Ricker wavelet function. The result is a normal Tensor - you
# can use whatever Tensor you want as the source amplitude.
source_amplitudes_true = (deepwave.wavelets.ricker(freq, nt, dt, 1/freq)
                          .reshape(-1, 1, 1)
                          .repeat(1, num_shots, num_sources_per_shot))

# %%
#RB Generate a cte velocy model (with water velocity)
mat2 = np.ones((nz,ny),np.float32)*1500.

mat2[nz-1,int(ny/2)]=max1  # put a pixel with true upper velocity to fix a propagator problem

# %%
#RB Create a smoothed model

#RB start with true model
mat3 = np.copy(mat)
#RB Filter image heavly
mat3 = scipy.ndimage.gaussian_filter(mat3,sigma=sigma) #10,50  #5%,10%
#for i in range(201):
#    mat3[:,i] = scipy.ndimage.gaussian_filter1d(mat3[:,i],sigma=20)
if plot==True:
    plt.figure(figsize=(12, 3))
    plt.imshow(mat3,vmin=min1,vmax=max1)
    plt.title('mat3 smoothed from true model')
    plt.colorbar()

    
#mat3 = 2200*np.ones(np.shape(mat))
#RB Force water table to be 1500 m/s (avoid imperfect direct wav removal)    
mat3[(mat==1500.0)]=1500.

#mat3[27:-1,:]=2800.
#RB Plot model
if plot==True:
    plt.figure(figsize=(12, 3))
    plt.imshow(mat3,vmin=min1,vmax=max1)
    plt.title('mat3 fixed water table')
    plt.colorbar()

#RB We may want to smooth the water table transition
#RB but I think it's a bad idea (not tested)
# mat3 = scipy.ndimage.gaussian_filter(mat3,sigma=4)

#RB Optionally we may import a initial model from file
#filename='Marm151_401_smooth.mat'
#mat3=scipy.io.loadmat(filename)['vel0']

#RB Ensure that the initial model has the same range of the true model by
#RB forcing one of its slowest pixel to have the true's model lower velocity and
#RB forcing one of its fastest pixel to have the true's model upper velocity
#RB find max & min values of mat3
smin=np.min(mat3)
smax=np.max(mat3)
indmin = np.where(mat3==smin)
indmax = np.where(mat3==smax)
# Take first pixel with minimum velocity and force it to true's model minimum velocity
mat3[indmin[0][0],indmin[1][0]]=min1
# Take first pixel with maximum velocity and force it to true's model maximum velocity
mat3[indmax[0][0],indmax[1][0]]=max1

# %%
#RB Convert models to PyTorch Tensors
model_true = torch.Tensor(mat) # Convert to a PyTorch Tensor
model_cte = torch.Tensor(mat2) # Convert to a PyTorch Tensor

# %%
###### Create 'true' data 
prop = deepwave.scalar.Propagator({'vp': model_true.to(device)}, dx)
receiver_amplitudes_all = prop(source_amplitudes_true.to(device),
                                x_s.to(device),
                                x_r.to(device), dt).cpu()
seis=np.squeeze(receiver_amplitudes_all.cpu().detach().numpy())
print(np.std(seis))
#seis = seis.swapaxes(1,2)
#seis = seis.swapaxes(0,1)
#receiver_amplitudes_all = receiver_amplitudes_all.swapaxes(1,2)
# Out:
# 0.5782329

# %%
seis = seis + np.random.normal(seis,0.05*np.std(seis))

# %%
if plot==True:
    plt.figure(figsize=(12, 3))
    plt.imshow(receiver_amplitudes_all[:,2].cpu().detach().numpy(),'Greys',vmin=-.1,vmax=.1, aspect='auto')
    
    plt.title('Model seismogram')

# %%
#with noise
if plot==True:
    plt.figure(figsize=(12, 3))
    plt.imshow(seis[:,2],'Greys',aspect='auto')
    
    plt.title('Model seismogram')

# %%
# Create direct arrivals data
prop2 = deepwave.scalar.Propagator({'vp': model_cte.to(device)}, dx)
receiver_amplitudes_cte = prop2(source_amplitudes_true.to(device),
                                x_s.to(device),
                                x_r.to(device), dt).cpu()

# %%
if plot==True:
    plt.figure(figsize=(12, 3))
    plt.imshow(receiver_amplitudes_cte[:,2].cpu().detach().numpy(),vmin=-.05,vmax=.05, aspect='auto')
    plt.title('Direct wave seismogram')

# %%
# Exclude direct waves from true data (they don't bring info from subsurface)
receiver_amplitudes_true = receiver_amplitudes_all

# %%
if plot==True:
    plt.figure(figsize=(12, 3))
    plt.imshow(receiver_amplitudes_true[:,2].cpu().detach().numpy(),vmin=-.05,vmax=.05, aspect='auto')
    plt.title('Model seismogram w direct waves removed')

# %%
#RB Normalize initial model to (-1,1) range
#model_init = (mat3-med)/wid
#RB_No_normalization
model_init = mat3

# %%
# Convert to Pytorch tensor
#model_init = torch.from_numpy(np.float32(model_init))
model_init = torch.Tensor(model_init)

# Make a copy so at the end we can see how far we came from the initial model
model = model_init.clone()
model = model.to(device)
model.requires_grad = True

# %%
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/')

          
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainA')
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainB')
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainC')
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainD')

os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testA')
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testB')
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testC')
os.system('rm -rf /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testD')

os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainA')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainB')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainC')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainD')

os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testA')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testB')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testC')
os.system('mkdir /disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testD')
# Out:
# 0

# %%
plt.figure(figsize=(12, 8))
plt.imshow(mat3,vmin=1500,vmax=3550,cmap='jet',aspect='auto')
plt.colorbar()

# %%
seis = seis.swapaxes(0,1)
#mat3 = 2200*np.ones(np.shape(mat))
#mat3[0:26,:] = 1500
A = seis
B = mat
C = mat3

for kk in range(1,2):
    
    #kk = 1
    D = torch.randn([1,8])
            
    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainA/'+str(kk)+'.npy','wb')
    np.save(file,A)
    file.close()

    
    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainB/'+str(kk)+'.npy','wb')
    np.save(file,B)
    file.close()


    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainC/'+str(kk)+'.npy','wb')
    np.save(file,C)
    file.close()

    
    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/trainD/'+str(kk)+'.npy','wb')
    np.save(file,D)
    file.close()

# %%
for kk in range(150,151):
    
    #kk = 1
    #D = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi/ZZConstant0ep'+str(kk)+'.npy')
            
    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testA/'+str(kk)+'.npy','wb')
    np.save(file,A)
    file.close()
    

    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testB/'+str(kk)+'.npy','wb')
    np.save(file,B)
    file.close()


    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testC/'+str(kk)+'.npy','wb')
    np.save(file,C)
    file.close()
    

    file = open('/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/MarmousiF/testD/'+str(kk)+'.npy','wb')
    np.save(file,D)
    file.close()

# %%
np.shape(seis)
# Out:
# (18, 4001, 200)

# %%
plt.figure(figsize=(12,8))
plt.imshow(seis[5,:,:],aspect=0.03,vmin=-0.1,vmax=0.1,)

# %%
nx = np.shape(mat)[1]
nz = np.shape(mat)[0]
dx = 10
par = {'extent': [0, nx*dx/1000, nz*dx/1000, 0]}
plt.figure(figsize=(12,8))
im = plt.imshow(mat/1000,'jet',**par)
ax = plt.gca(); 
divider = make_axes_locatable(ax); cax = divider.append_axes("right", size="5%", pad=0.05); plt.colorbar(im, cax=cax, label='km/s'); plt.pause
# Out:
# <function matplotlib.pyplot.pause(interval)>

# %%
from skimage.metrics import mean_squared_error
from skimage.metrics import structural_similarity as ssim
inverted = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeNADR40ep2000.npy')
inverted = inverted[0,0,:,:]
plt.figure(figsize=(12,8))
im = plt.imshow(inverted,'jet',**par)
ax = plt.gca(); 
divider = make_axes_locatable(ax); cax = divider.append_axes("right", size="5%", pad=0.05); plt.colorbar(im, cax=cax, label='km/s'); plt.pause
mse = mean_squared_error(mat/1000,inverted/1000)
ssim = ssim(mat/1000,inverted/1000)
print("mse :", mse)
print("ssim :", ssim)
# Out:
# mse : 0.04511668509366746
# ssim : 0.6954743003254124

# %%
rows = 1
columns = 4
fig1 = plt.figure(figsize=(12,9))

ax = fig1.add_subplot(rows,columns,1)

x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(inverted[:,25]/1000,x, linewidth=2.5)
plt.plot(mat[:,25]/1000,x, linewidth=2.5)
plt.tight_layout()
plt.xlabel('vp(km/s), x=0.25 km')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()
#ax.set_ylim(ymin=0)

ax = fig1.add_subplot(rows,columns,2)

x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(inverted[:,80]/1000,x, linewidth=2.5)
plt.plot(mat[:,80]/1000,x, linewidth=2.5)
plt.tight_layout()
plt.xlabel('vp(km/s), x=0.8 km')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()

ax = fig1.add_subplot(rows,columns,3)

x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(inverted[:,120]/1000,x, linewidth=2.5)
plt.plot(mat[:,120]/1000,x, linewidth=2.5)
plt.tight_layout()
plt.xlabel('vp(km/s), x=1.2 km')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()

ax = fig1.add_subplot(rows,columns,4)

x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(inverted[:,150]/1000,x, linewidth=2.5)
plt.plot(mat[:,150]/1000,x, linewidth=2.5)
plt.tight_layout()
plt.xlabel('vp(km/s), x=1.5 km')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()


#plt.invert_yaxis()
#plt.plot(mat[:,75]/1000)

# %%
np.max(mat)
# Out:
# 4766.604

# %%
with open('/disk/student/adhara/Fall2021/PhysicsBasedFWI/checkpoints/marmousiconvergence/loss_log.txt') as f:
    lines = f.readlines()

# %%
len(lines)
# Out:
# 4001

# %%
lines
# Out:
# ['================ Training Loss (Wed Dec  1 09:45:55 2021) ================\n',
#  '(epoch: 1, iters: 8) Modelloss: 517550.406 Dataloss: 0.025 Validationloss: 511425.219 KL divergence: 0.000 \n',
#  '(epoch: 2, iters: 8) Modelloss: 514779.844 Dataloss: 0.026 Validationloss: 511793.781 KL divergence: 0.000 \n',
#  '(epoch: 3, iters: 8) Modelloss: 529015.250 Dataloss: 0.026 Validationloss: 1424652.250 KL divergence: 0.000 \n',
#  '(epoch: 4, iters: 8) Modelloss: 529551.000 Dataloss: 0.025 Validationloss: 2208480.500 KL divergence: 0.000 \n',
#  '(epoch: 5, iters: 8) Modelloss: 508985.750 Dataloss: 0.023 Validationloss: 2874039.250 KL divergence: 0.000 \n',
#  '(epoch: 6, iters: 8) Modelloss: 522041.688 Dataloss: 0.023 Validationloss: 2864442.750 KL divergence: 0.000 \n',
#  '(epoch: 7, iters: 8) Modelloss: 515437.156 Dataloss: 0.022 Validationloss: 2166769.000 KL divergence: 0.000 \n',
#  '(epoch: 8, iters: 8) Modelloss: 512503.281 Dataloss: 0.021 Validationloss: 1985678.500 KL divergence: 0.000 \n',
#  '(epoch: 9, iters: 8) Modelloss: 516984.625 Dataloss: 0.021 Validationloss: 1889296.500 KL divergence: 0.000 \n',
#  '(epoch: 10, iters: 8) Modelloss: 515858.406 Dataloss: 0.022 Validationloss: 1748365.875 KL divergence: 0.000 \n',
#  '(epoch: 11, iters: 8) Modelloss: 504266.062 Dataloss: 0.022 Validationloss: 1660981.625 KL divergence: 0.000 \n',
#  '(epoch: 12, iters: 8) Modelloss: 495190.656 Dataloss: 0.021 Validationloss: 1570558.000 KL divergence: 0.000 \n',
#  '(epoch: 13, iters: 8) Modelloss: 493110.438 Dataloss: 0.021 Validationloss: 1501755.875 KL divergence: 0.000 \n',
#  '(epoch: 14, iters: 8) Modelloss: 493214.719 Dataloss: 0.020 Validationloss: 1474777.875 KL divergence: 0.000 \n',
#  '(epoch: 15, iters: 8) Modelloss: 493746.594 Dataloss: 0.021 Validationloss: 1383731.250 KL divergence: 0.000 \n',
#  '(epoch: 16, iters: 8) Modelloss: 495990.500 Dataloss: 0.022 Validationloss: 1276955.625 KL divergence: 0.000 \n',
#  '(epoch: 17, iters: 8) Modelloss: 500269.781 Dataloss: 0.021 Validationloss: 1193429.250 KL divergence: 0.000 \n',
#  '(epoch: 18, iters: 8) Modelloss: 503042.969 Dataloss: 0.020 Validationloss: 1133380.625 KL divergence: 0.000 \n',
#  '(epoch: 19, iters: 8) Modelloss: 492173.875 Dataloss: 0.019 Validationloss: 1087404.125 KL divergence: 0.000 \n',
#  '(epoch: 20, iters: 8) Modelloss: 479954.188 Dataloss: 0.019 Validationloss: 1035136.875 KL divergence: 0.000 \n',
#  '(epoch: 21, iters: 8) Modelloss: 468565.094 Dataloss: 0.018 Validationloss: 954412.500 KL divergence: 0.000 \n',
#  '(epoch: 22, iters: 8) Modelloss: 466255.344 Dataloss: 0.018 Validationloss: 859464.562 KL divergence: 0.000 \n',
#  '(epoch: 23, iters: 8) Modelloss: 470447.562 Dataloss: 0.018 Validationloss: 783830.625 KL divergence: 0.000 \n',
#  '(epoch: 24, iters: 8) Modelloss: 471810.750 Dataloss: 0.018 Validationloss: 746595.438 KL divergence: 0.000 \n',
#  '(epoch: 25, iters: 8) Modelloss: 466114.406 Dataloss: 0.017 Validationloss: 737995.750 KL divergence: 0.000 \n',
#  '(epoch: 26, iters: 8) Modelloss: 463641.344 Dataloss: 0.017 Validationloss: 706835.312 KL divergence: 0.000 \n',
#  '(epoch: 27, iters: 8) Modelloss: 467289.750 Dataloss: 0.016 Validationloss: 658278.938 KL divergence: 0.000 \n',
#  '(epoch: 28, iters: 8) Modelloss: 468074.844 Dataloss: 0.016 Validationloss: 613240.625 KL divergence: 0.000 \n',
#  '(epoch: 29, iters: 8) Modelloss: 460441.844 Dataloss: 0.016 Validationloss: 581334.750 KL divergence: 0.000 \n',
#  '(epoch: 30, iters: 8) Modelloss: 453487.250 Dataloss: 0.015 Validationloss: 563493.875 KL divergence: 0.000 \n',
#  '(epoch: 31, iters: 8) Modelloss: 447713.188 Dataloss: 0.015 Validationloss: 548784.562 KL divergence: 0.000 \n',
#  '(epoch: 32, iters: 8) Modelloss: 442917.750 Dataloss: 0.015 Validationloss: 513907.875 KL divergence: 0.000 \n',
#  '(epoch: 33, iters: 8) Modelloss: 436253.531 Dataloss: 0.015 Validationloss: 475385.656 KL divergence: 0.000 \n',
#  '(epoch: 34, iters: 8) Modelloss: 431496.844 Dataloss: 0.014 Validationloss: 459183.469 KL divergence: 0.000 \n',
#  '(epoch: 35, iters: 8) Modelloss: 424578.219 Dataloss: 0.015 Validationloss: 437177.656 KL divergence: 0.000 \n',
#  '(epoch: 36, iters: 8) Modelloss: 422756.625 Dataloss: 0.014 Validationloss: 419258.875 KL divergence: 0.000 \n',
#  '(epoch: 37, iters: 8) Modelloss: 425644.906 Dataloss: 0.016 Validationloss: 419594.344 KL divergence: 0.000 \n',
#  '(epoch: 38, iters: 8) Modelloss: 420612.250 Dataloss: 0.014 Validationloss: 396042.219 KL divergence: 0.000 \n',
#  '(epoch: 39, iters: 8) Modelloss: 417126.062 Dataloss: 0.015 Validationloss: 395526.469 KL divergence: 0.000 \n',
#  '(epoch: 40, iters: 8) Modelloss: 424347.844 Dataloss: 0.016 Validationloss: 406295.656 KL divergence: 0.000 \n',
#  '(epoch: 41, iters: 8) Modelloss: 426998.312 Dataloss: 0.015 Validationloss: 399648.094 KL divergence: 0.000 \n',
#  '(epoch: 42, iters: 8) Modelloss: 424278.469 Dataloss: 0.014 Validationloss: 381498.438 KL divergence: 0.000 \n',
#  '(epoch: 43, iters: 8) Modelloss: 423487.125 Dataloss: 0.015 Validationloss: 376156.469 KL divergence: 0.000 \n',
#  '(epoch: 44, iters: 8) Modelloss: 422234.906 Dataloss: 0.014 Validationloss: 365357.094 KL divergence: 0.000 \n',
#  '(epoch: 45, iters: 8) Modelloss: 414778.375 Dataloss: 0.014 Validationloss: 369851.188 KL divergence: 0.000 \n',
#  '(epoch: 46, iters: 8) Modelloss: 406930.625 Dataloss: 0.013 Validationloss: 386263.688 KL divergence: 0.000 \n',
#  '(epoch: 47, iters: 8) Modelloss: 402710.281 Dataloss: 0.013 Validationloss: 393821.500 KL divergence: 0.000 \n',
#  '(epoch: 48, iters: 8) Modelloss: 409195.750 Dataloss: 0.012 Validationloss: 389079.281 KL divergence: 0.000 \n',
#  '(epoch: 49, iters: 8) Modelloss: 417607.594 Dataloss: 0.012 Validationloss: 383796.750 KL divergence: 0.000 \n',
#  '(epoch: 50, iters: 8) Modelloss: 415496.656 Dataloss: 0.012 Validationloss: 390752.906 KL divergence: 0.000 \n',
#  '(epoch: 51, iters: 8) Modelloss: 404615.000 Dataloss: 0.011 Validationloss: 397001.188 KL divergence: 0.000 \n',
#  '(epoch: 52, iters: 8) Modelloss: 401256.219 Dataloss: 0.011 Validationloss: 391409.594 KL divergence: 0.000 \n',
#  '(epoch: 53, iters: 8) Modelloss: 409658.719 Dataloss: 0.010 Validationloss: 370865.594 KL divergence: 0.000 \n',
#  '(epoch: 54, iters: 8) Modelloss: 410292.375 Dataloss: 0.011 Validationloss: 361821.500 KL divergence: 0.000 \n',
#  '(epoch: 55, iters: 8) Modelloss: 407403.969 Dataloss: 0.010 Validationloss: 371474.969 KL divergence: 0.000 \n',
#  '(epoch: 56, iters: 8) Modelloss: 406706.500 Dataloss: 0.011 Validationloss: 377077.000 KL divergence: 0.000 \n',
#  '(epoch: 57, iters: 8) Modelloss: 405152.906 Dataloss: 0.011 Validationloss: 378694.688 KL divergence: 0.000 \n',
#  '(epoch: 58, iters: 8) Modelloss: 404639.875 Dataloss: 0.010 Validationloss: 377154.281 KL divergence: 0.000 \n',
#  '(epoch: 59, iters: 8) Modelloss: 401535.812 Dataloss: 0.010 Validationloss: 383870.594 KL divergence: 0.000 \n',
#  '(epoch: 60, iters: 8) Modelloss: 400863.438 Dataloss: 0.009 Validationloss: 381699.438 KL divergence: 0.000 \n',
#  '(epoch: 61, iters: 8) Modelloss: 410874.375 Dataloss: 0.010 Validationloss: 377943.625 KL divergence: 0.000 \n',
#  '(epoch: 62, iters: 8) Modelloss: 415988.688 Dataloss: 0.010 Validationloss: 388134.906 KL divergence: 0.000 \n',
#  '(epoch: 63, iters: 8) Modelloss: 410355.156 Dataloss: 0.009 Validationloss: 392951.844 KL divergence: 0.000 \n',
#  '(epoch: 64, iters: 8) Modelloss: 403260.938 Dataloss: 0.008 Validationloss: 390674.500 KL divergence: 0.000 \n',
#  '(epoch: 65, iters: 8) Modelloss: 405063.125 Dataloss: 0.008 Validationloss: 383525.469 KL divergence: 0.000 \n',
#  '(epoch: 66, iters: 8) Modelloss: 402868.625 Dataloss: 0.008 Validationloss: 384250.219 KL divergence: 0.000 \n',
#  '(epoch: 67, iters: 8) Modelloss: 402605.062 Dataloss: 0.008 Validationloss: 386639.312 KL divergence: 0.000 \n',
#  '(epoch: 68, iters: 8) Modelloss: 404421.906 Dataloss: 0.008 Validationloss: 395278.625 KL divergence: 0.000 \n',
#  '(epoch: 69, iters: 8) Modelloss: 400646.688 Dataloss: 0.008 Validationloss: 402580.812 KL divergence: 0.000 \n',
#  '(epoch: 70, iters: 8) Modelloss: 400082.125 Dataloss: 0.010 Validationloss: 408643.375 KL divergence: 0.000 \n',
#  '(epoch: 71, iters: 8) Modelloss: 404582.438 Dataloss: 0.008 Validationloss: 386782.062 KL divergence: 0.000 \n',
#  '(epoch: 72, iters: 8) Modelloss: 406392.406 Dataloss: 0.010 Validationloss: 385226.406 KL divergence: 0.000 \n',
#  '(epoch: 73, iters: 8) Modelloss: 404300.406 Dataloss: 0.011 Validationloss: 409397.031 KL divergence: 0.000 \n',
#  '(epoch: 74, iters: 8) Modelloss: 403355.125 Dataloss: 0.008 Validationloss: 404303.625 KL divergence: 0.000 \n',
#  '(epoch: 75, iters: 8) Modelloss: 402638.531 Dataloss: 0.012 Validationloss: 382082.250 KL divergence: 0.000 \n',
#  '(epoch: 76, iters: 8) Modelloss: 406181.094 Dataloss: 0.009 Validationloss: 368645.312 KL divergence: 0.000 \n',
#  '(epoch: 77, iters: 8) Modelloss: 402856.031 Dataloss: 0.009 Validationloss: 369402.969 KL divergence: 0.000 \n',
#  '(epoch: 78, iters: 8) Modelloss: 400047.406 Dataloss: 0.008 Validationloss: 381569.469 KL divergence: 0.000 \n',
#  '(epoch: 79, iters: 8) Modelloss: 406915.594 Dataloss: 0.010 Validationloss: 390677.406 KL divergence: 0.000 \n',
#  '(epoch: 80, iters: 8) Modelloss: 416885.719 Dataloss: 0.008 Validationloss: 397042.406 KL divergence: 0.000 \n',
#  '(epoch: 81, iters: 8) Modelloss: 415944.312 Dataloss: 0.008 Validationloss: 402045.031 KL divergence: 0.000 \n',
#  '(epoch: 82, iters: 8) Modelloss: 406666.594 Dataloss: 0.008 Validationloss: 410097.938 KL divergence: 0.000 \n',
#  '(epoch: 83, iters: 8) Modelloss: 401021.500 Dataloss: 0.008 Validationloss: 409474.281 KL divergence: 0.000 \n',
#  '(epoch: 84, iters: 8) Modelloss: 403521.219 Dataloss: 0.008 Validationloss: 397885.125 KL divergence: 0.000 \n',
#  '(epoch: 85, iters: 8) Modelloss: 408314.375 Dataloss: 0.008 Validationloss: 385148.656 KL divergence: 0.000 \n',
#  '(epoch: 86, iters: 8) Modelloss: 405732.281 Dataloss: 0.008 Validationloss: 390358.750 KL divergence: 0.000 \n',
#  '(epoch: 87, iters: 8) Modelloss: 402133.844 Dataloss: 0.008 Validationloss: 404996.469 KL divergence: 0.000 \n',
#  '(epoch: 88, iters: 8) Modelloss: 400617.281 Dataloss: 0.008 Validationloss: 405598.875 KL divergence: 0.000 \n',
#  '(epoch: 89, iters: 8) Modelloss: 404821.156 Dataloss: 0.007 Validationloss: 398024.250 KL divergence: 0.000 \n',
#  '(epoch: 90, iters: 8) Modelloss: 415393.250 Dataloss: 0.007 Validationloss: 400532.750 KL divergence: 0.000 \n',
#  '(epoch: 91, iters: 8) Modelloss: 415646.125 Dataloss: 0.007 Validationloss: 405750.625 KL divergence: 0.000 \n',
#  '(epoch: 92, iters: 8) Modelloss: 410612.531 Dataloss: 0.007 Validationloss: 405311.781 KL divergence: 0.000 \n',
#  '(epoch: 93, iters: 8) Modelloss: 406908.938 Dataloss: 0.008 Validationloss: 401817.906 KL divergence: 0.000 \n',
#  '(epoch: 94, iters: 8) Modelloss: 402300.812 Dataloss: 0.007 Validationloss: 397288.375 KL divergence: 0.000 \n',
#  '(epoch: 95, iters: 8) Modelloss: 400839.719 Dataloss: 0.008 Validationloss: 397887.719 KL divergence: 0.000 \n',
#  '(epoch: 96, iters: 8) Modelloss: 403718.219 Dataloss: 0.008 Validationloss: 409703.812 KL divergence: 0.000 \n',
#  '(epoch: 97, iters: 8) Modelloss: 410402.094 Dataloss: 0.008 Validationloss: 408892.000 KL divergence: 0.000 \n',
#  '(epoch: 98, iters: 8) Modelloss: 415269.344 Dataloss: 0.010 Validationloss: 401973.156 KL divergence: 0.000 \n',
#  '(epoch: 99, iters: 8) Modelloss: 414263.344 Dataloss: 0.007 Validationloss: 400887.906 KL divergence: 0.000 \n',
#  '(epoch: 100, iters: 8) Modelloss: 404441.000 Dataloss: 0.010 Validationloss: 403444.438 KL divergence: 0.000 \n',
#  '(epoch: 101, iters: 8) Modelloss: 402073.500 Dataloss: 0.007 Validationloss: 395209.719 KL divergence: 0.000 \n',
#  '(epoch: 102, iters: 8) Modelloss: 408237.938 Dataloss: 0.009 Validationloss: 392865.625 KL divergence: 0.000 \n',
#  '(epoch: 103, iters: 8) Modelloss: 415376.156 Dataloss: 0.008 Validationloss: 399227.156 KL divergence: 0.000 \n',
#  '(epoch: 104, iters: 8) Modelloss: 414966.281 Dataloss: 0.009 Validationloss: 410311.344 KL divergence: 0.000 \n',
#  '(epoch: 105, iters: 8) Modelloss: 409621.688 Dataloss: 0.010 Validationloss: 406512.406 KL divergence: 0.000 \n',
#  '(epoch: 106, iters: 8) Modelloss: 410304.406 Dataloss: 0.009 Validationloss: 392106.375 KL divergence: 0.000 \n',
#  '(epoch: 107, iters: 8) Modelloss: 418444.625 Dataloss: 0.008 Validationloss: 389733.375 KL divergence: 0.000 \n',
#  '(epoch: 108, iters: 8) Modelloss: 416176.625 Dataloss: 0.008 Validationloss: 392955.844 KL divergence: 0.000 \n',
#  '(epoch: 109, iters: 8) Modelloss: 408029.250 Dataloss: 0.009 Validationloss: 396256.188 KL divergence: 0.000 \n',
#  '(epoch: 110, iters: 8) Modelloss: 399918.156 Dataloss: 0.007 Validationloss: 392130.188 KL divergence: 0.000 \n',
#  '(epoch: 111, iters: 8) Modelloss: 403360.156 Dataloss: 0.008 Validationloss: 387059.969 KL divergence: 0.000 \n',
#  '(epoch: 112, iters: 8) Modelloss: 412231.875 Dataloss: 0.008 Validationloss: 389870.812 KL divergence: 0.000 \n',
#  '(epoch: 113, iters: 8) Modelloss: 412644.094 Dataloss: 0.008 Validationloss: 396342.688 KL divergence: 0.000 \n',
#  '(epoch: 114, iters: 8) Modelloss: 406907.094 Dataloss: 0.007 Validationloss: 401563.469 KL divergence: 0.000 \n',
#  '(epoch: 115, iters: 8) Modelloss: 400658.500 Dataloss: 0.008 Validationloss: 405675.156 KL divergence: 0.000 \n',
#  '(epoch: 116, iters: 8) Modelloss: 402204.562 Dataloss: 0.007 Validationloss: 403373.031 KL divergence: 0.000 \n',
#  '(epoch: 117, iters: 8) Modelloss: 408501.781 Dataloss: 0.007 Validationloss: 394227.094 KL divergence: 0.000 \n',
#  '(epoch: 118, iters: 8) Modelloss: 410757.906 Dataloss: 0.007 Validationloss: 392417.656 KL divergence: 0.000 \n',
#  '(epoch: 119, iters: 8) Modelloss: 403562.469 Dataloss: 0.006 Validationloss: 396720.562 KL divergence: 0.000 \n',
#  '(epoch: 120, iters: 8) Modelloss: 399498.719 Dataloss: 0.007 Validationloss: 402450.969 KL divergence: 0.000 \n',
#  '(epoch: 121, iters: 8) Modelloss: 402652.062 Dataloss: 0.006 Validationloss: 397766.594 KL divergence: 0.000 \n',
#  '(epoch: 122, iters: 8) Modelloss: 406888.938 Dataloss: 0.006 Validationloss: 391198.031 KL divergence: 0.000 \n',
#  '(epoch: 123, iters: 8) Modelloss: 405861.188 Dataloss: 0.007 Validationloss: 391240.531 KL divergence: 0.000 \n',
#  '(epoch: 124, iters: 8) Modelloss: 400179.844 Dataloss: 0.007 Validationloss: 398884.188 KL divergence: 0.000 \n',
#  '(epoch: 125, iters: 8) Modelloss: 398073.438 Dataloss: 0.006 Validationloss: 400630.844 KL divergence: 0.000 \n',
#  '(epoch: 126, iters: 8) Modelloss: 402407.500 Dataloss: 0.007 Validationloss: 394943.562 KL divergence: 0.000 \n',
#  '(epoch: 127, iters: 8) Modelloss: 404969.125 Dataloss: 0.007 Validationloss: 389546.531 KL divergence: 0.000 \n',
#  '(epoch: 128, iters: 8) Modelloss: 400672.812 Dataloss: 0.007 Validationloss: 386245.094 KL divergence: 0.000 \n',
#  '(epoch: 129, iters: 8) Modelloss: 394348.969 Dataloss: 0.006 Validationloss: 384868.875 KL divergence: 0.000 \n',
#  '(epoch: 130, iters: 8) Modelloss: 392850.344 Dataloss: 0.007 Validationloss: 391541.531 KL divergence: 0.000 \n',
#  '(epoch: 131, iters: 8) Modelloss: 399529.125 Dataloss: 0.006 Validationloss: 398946.188 KL divergence: 0.000 \n',
#  '(epoch: 132, iters: 8) Modelloss: 403768.625 Dataloss: 0.006 Validationloss: 401636.719 KL divergence: 0.000 \n',
#  '(epoch: 133, iters: 8) Modelloss: 401619.875 Dataloss: 0.006 Validationloss: 401939.938 KL divergence: 0.000 \n',
#  '(epoch: 134, iters: 8) Modelloss: 396670.500 Dataloss: 0.005 Validationloss: 402455.344 KL divergence: 0.000 \n',
#  '(epoch: 135, iters: 8) Modelloss: 398547.969 Dataloss: 0.006 Validationloss: 401002.594 KL divergence: 0.000 \n',
#  '(epoch: 136, iters: 8) Modelloss: 398995.531 Dataloss: 0.006 Validationloss: 398966.375 KL divergence: 0.000 \n',
#  '(epoch: 137, iters: 8) Modelloss: 396165.781 Dataloss: 0.006 Validationloss: 403366.281 KL divergence: 0.000 \n',
#  '(epoch: 138, iters: 8) Modelloss: 393287.031 Dataloss: 0.006 Validationloss: 406343.469 KL divergence: 0.000 \n',
#  '(epoch: 139, iters: 8) Modelloss: 394353.312 Dataloss: 0.006 Validationloss: 398956.625 KL divergence: 0.000 \n',
#  '(epoch: 140, iters: 8) Modelloss: 395908.438 Dataloss: 0.006 Validationloss: 396371.344 KL divergence: 0.000 \n',
#  '(epoch: 141, iters: 8) Modelloss: 394068.688 Dataloss: 0.005 Validationloss: 391497.562 KL divergence: 0.000 \n',
#  '(epoch: 142, iters: 8) Modelloss: 391219.406 Dataloss: 0.006 Validationloss: 390454.969 KL divergence: 0.000 \n',
#  '(epoch: 143, iters: 8) Modelloss: 392079.625 Dataloss: 0.006 Validationloss: 395050.219 KL divergence: 0.000 \n',
#  '(epoch: 144, iters: 8) Modelloss: 392939.656 Dataloss: 0.005 Validationloss: 388460.688 KL divergence: 0.000 \n',
#  '(epoch: 145, iters: 8) Modelloss: 391718.844 Dataloss: 0.007 Validationloss: 382636.844 KL divergence: 0.000 \n',
#  '(epoch: 146, iters: 8) Modelloss: 391834.312 Dataloss: 0.005 Validationloss: 386040.250 KL divergence: 0.000 \n',
#  '(epoch: 147, iters: 8) Modelloss: 392646.094 Dataloss: 0.006 Validationloss: 391752.219 KL divergence: 0.000 \n',
#  '(epoch: 148, iters: 8) Modelloss: 394670.250 Dataloss: 0.006 Validationloss: 388002.125 KL divergence: 0.000 \n',
#  '(epoch: 149, iters: 8) Modelloss: 394237.906 Dataloss: 0.005 Validationloss: 391052.500 KL divergence: 0.000 \n',
#  '(epoch: 150, iters: 8) Modelloss: 390894.281 Dataloss: 0.006 Validationloss: 391547.312 KL divergence: 0.000 \n',
#  '(epoch: 151, iters: 8) Modelloss: 390425.469 Dataloss: 0.006 Validationloss: 387320.812 KL divergence: 0.000 \n',
#  '(epoch: 152, iters: 8) Modelloss: 392710.156 Dataloss: 0.005 Validationloss: 391782.312 KL divergence: 0.000 \n',
#  '(epoch: 153, iters: 8) Modelloss: 393843.781 Dataloss: 0.005 Validationloss: 393773.031 KL divergence: 0.000 \n',
#  '(epoch: 154, iters: 8) Modelloss: 393274.156 Dataloss: 0.005 Validationloss: 397589.750 KL divergence: 0.000 \n',
#  '(epoch: 155, iters: 8) Modelloss: 392654.625 Dataloss: 0.005 Validationloss: 399997.062 KL divergence: 0.000 \n',
#  '(epoch: 156, iters: 8) Modelloss: 393522.094 Dataloss: 0.005 Validationloss: 394435.875 KL divergence: 0.000 \n',
#  '(epoch: 157, iters: 8) Modelloss: 391925.719 Dataloss: 0.005 Validationloss: 392794.250 KL divergence: 0.000 \n',
#  '(epoch: 158, iters: 8) Modelloss: 391287.844 Dataloss: 0.005 Validationloss: 391693.750 KL divergence: 0.000 \n',
#  '(epoch: 159, iters: 8) Modelloss: 392637.469 Dataloss: 0.005 Validationloss: 391867.250 KL divergence: 0.000 \n',
#  '(epoch: 160, iters: 8) Modelloss: 391833.750 Dataloss: 0.005 Validationloss: 393560.406 KL divergence: 0.000 \n',
#  '(epoch: 161, iters: 8) Modelloss: 390137.281 Dataloss: 0.006 Validationloss: 387884.125 KL divergence: 0.000 \n',
#  '(epoch: 162, iters: 8) Modelloss: 389884.875 Dataloss: 0.005 Validationloss: 388521.188 KL divergence: 0.000 \n',
#  '(epoch: 163, iters: 8) Modelloss: 390466.969 Dataloss: 0.005 Validationloss: 392566.375 KL divergence: 0.000 \n',
#  '(epoch: 164, iters: 8) Modelloss: 390061.719 Dataloss: 0.005 Validationloss: 391030.281 KL divergence: 0.000 \n',
#  '(epoch: 165, iters: 8) Modelloss: 390988.500 Dataloss: 0.005 Validationloss: 393644.188 KL divergence: 0.000 \n',
#  '(epoch: 166, iters: 8) Modelloss: 392391.969 Dataloss: 0.005 Validationloss: 394981.094 KL divergence: 0.000 \n',
#  '(epoch: 167, iters: 8) Modelloss: 391619.094 Dataloss: 0.005 Validationloss: 397186.188 KL divergence: 0.000 \n',
#  '(epoch: 168, iters: 8) Modelloss: 388231.406 Dataloss: 0.005 Validationloss: 390534.500 KL divergence: 0.000 \n',
#  '(epoch: 169, iters: 8) Modelloss: 388073.062 Dataloss: 0.005 Validationloss: 387745.438 KL divergence: 0.000 \n',
#  '(epoch: 170, iters: 8) Modelloss: 388717.219 Dataloss: 0.005 Validationloss: 391951.406 KL divergence: 0.000 \n',
#  '(epoch: 171, iters: 8) Modelloss: 390852.188 Dataloss: 0.005 Validationloss: 397237.719 KL divergence: 0.000 \n',
#  '(epoch: 172, iters: 8) Modelloss: 389313.875 Dataloss: 0.004 Validationloss: 395360.406 KL divergence: 0.000 \n',
#  '(epoch: 173, iters: 8) Modelloss: 385631.250 Dataloss: 0.005 Validationloss: 386176.219 KL divergence: 0.000 \n',
#  '(epoch: 174, iters: 8) Modelloss: 386077.688 Dataloss: 0.005 Validationloss: 384199.281 KL divergence: 0.000 \n',
#  '(epoch: 175, iters: 8) Modelloss: 388116.656 Dataloss: 0.005 Validationloss: 383096.594 KL divergence: 0.000 \n',
#  '(epoch: 176, iters: 8) Modelloss: 387083.312 Dataloss: 0.005 Validationloss: 392390.188 KL divergence: 0.000 \n',
#  '(epoch: 177, iters: 8) Modelloss: 387683.875 Dataloss: 0.005 Validationloss: 395514.094 KL divergence: 0.000 \n',
#  '(epoch: 178, iters: 8) Modelloss: 386181.656 Dataloss: 0.005 Validationloss: 386461.250 KL divergence: 0.000 \n',
#  '(epoch: 179, iters: 8) Modelloss: 382327.594 Dataloss: 0.005 Validationloss: 382837.125 KL divergence: 0.000 \n',
#  '(epoch: 180, iters: 8) Modelloss: 383070.500 Dataloss: 0.005 Validationloss: 378052.531 KL divergence: 0.000 \n',
#  '(epoch: 181, iters: 8) Modelloss: 387108.281 Dataloss: 0.005 Validationloss: 382304.094 KL divergence: 0.000 \n',
#  '(epoch: 182, iters: 8) Modelloss: 387612.406 Dataloss: 0.006 Validationloss: 392883.219 KL divergence: 0.000 \n',
#  '(epoch: 183, iters: 8) Modelloss: 387584.719 Dataloss: 0.005 Validationloss: 391472.406 KL divergence: 0.000 \n',
#  '(epoch: 184, iters: 8) Modelloss: 385813.312 Dataloss: 0.005 Validationloss: 386749.312 KL divergence: 0.000 \n',
#  '(epoch: 185, iters: 8) Modelloss: 385775.625 Dataloss: 0.005 Validationloss: 382765.500 KL divergence: 0.000 \n',
#  '(epoch: 186, iters: 8) Modelloss: 383013.156 Dataloss: 0.005 Validationloss: 380966.156 KL divergence: 0.000 \n',
#  '(epoch: 187, iters: 8) Modelloss: 383073.375 Dataloss: 0.005 Validationloss: 383204.438 KL divergence: 0.000 \n',
#  '(epoch: 188, iters: 8) Modelloss: 383917.844 Dataloss: 0.005 Validationloss: 378852.844 KL divergence: 0.000 \n',
#  '(epoch: 189, iters: 8) Modelloss: 384292.156 Dataloss: 0.004 Validationloss: 381078.531 KL divergence: 0.000 \n',
#  '(epoch: 190, iters: 8) Modelloss: 386101.094 Dataloss: 0.004 Validationloss: 383184.719 KL divergence: 0.000 \n',
#  '(epoch: 191, iters: 8) Modelloss: 382607.812 Dataloss: 0.005 Validationloss: 383020.594 KL divergence: 0.000 \n',
#  '(epoch: 192, iters: 8) Modelloss: 382192.656 Dataloss: 0.005 Validationloss: 380280.469 KL divergence: 0.000 \n',
#  '(epoch: 193, iters: 8) Modelloss: 382245.281 Dataloss: 0.005 Validationloss: 381963.500 KL divergence: 0.000 \n',
#  '(epoch: 194, iters: 8) Modelloss: 378293.875 Dataloss: 0.005 Validationloss: 379608.594 KL divergence: 0.000 \n',
#  '(epoch: 195, iters: 8) Modelloss: 381510.312 Dataloss: 0.006 Validationloss: 385306.500 KL divergence: 0.000 \n',
#  '(epoch: 196, iters: 8) Modelloss: 385355.062 Dataloss: 0.005 Validationloss: 386378.062 KL divergence: 0.000 \n',
#  '(epoch: 197, iters: 8) Modelloss: 381826.500 Dataloss: 0.006 Validationloss: 388151.562 KL divergence: 0.000 \n',
#  '(epoch: 198, iters: 8) Modelloss: 379411.656 Dataloss: 0.006 Validationloss: 387928.406 KL divergence: 0.000 \n',
#  '(epoch: 199, iters: 8) Modelloss: 379164.094 Dataloss: 0.005 Validationloss: 379005.531 KL divergence: 0.000 \n',
#  '(epoch: 200, iters: 8) Modelloss: 380082.719 Dataloss: 0.007 Validationloss: 371445.531 KL divergence: 0.000 \n',
#  '(epoch: 201, iters: 8) Modelloss: 382357.656 Dataloss: 0.005 Validationloss: 373836.875 KL divergence: 0.000 \n',
#  '(epoch: 202, iters: 8) Modelloss: 380785.719 Dataloss: 0.007 Validationloss: 380546.375 KL divergence: 0.000 \n',
#  '(epoch: 203, iters: 8) Modelloss: 380678.156 Dataloss: 0.006 Validationloss: 380387.562 KL divergence: 0.000 \n',
#  '(epoch: 204, iters: 8) Modelloss: 382180.875 Dataloss: 0.008 Validationloss: 374811.469 KL divergence: 0.000 \n',
#  '(epoch: 205, iters: 8) Modelloss: 386895.625 Dataloss: 0.006 Validationloss: 378309.781 KL divergence: 0.000 \n',
#  '(epoch: 206, iters: 8) Modelloss: 386606.719 Dataloss: 0.005 Validationloss: 382856.219 KL divergence: 0.000 \n',
#  '(epoch: 207, iters: 8) Modelloss: 379974.875 Dataloss: 0.005 Validationloss: 382066.938 KL divergence: 0.000 \n',
#  '(epoch: 208, iters: 8) Modelloss: 378826.281 Dataloss: 0.005 Validationloss: 375111.719 KL divergence: 0.000 \n',
#  '(epoch: 209, iters: 8) Modelloss: 382971.375 Dataloss: 0.005 Validationloss: 371628.844 KL divergence: 0.000 \n',
#  '(epoch: 210, iters: 8) Modelloss: 378778.312 Dataloss: 0.005 Validationloss: 369891.156 KL divergence: 0.000 \n',
#  '(epoch: 211, iters: 8) Modelloss: 372719.719 Dataloss: 0.005 Validationloss: 373394.219 KL divergence: 0.000 \n',
#  '(epoch: 212, iters: 8) Modelloss: 377393.688 Dataloss: 0.005 Validationloss: 382174.406 KL divergence: 0.000 \n',
#  '(epoch: 213, iters: 8) Modelloss: 382550.375 Dataloss: 0.005 Validationloss: 386616.000 KL divergence: 0.000 \n',
#  '(epoch: 214, iters: 8) Modelloss: 380080.062 Dataloss: 0.005 Validationloss: 384673.562 KL divergence: 0.000 \n',
#  '(epoch: 215, iters: 8) Modelloss: 376888.875 Dataloss: 0.005 Validationloss: 379640.094 KL divergence: 0.000 \n',
#  '(epoch: 216, iters: 8) Modelloss: 375097.625 Dataloss: 0.005 Validationloss: 372676.875 KL divergence: 0.000 \n',
#  '(epoch: 217, iters: 8) Modelloss: 375958.500 Dataloss: 0.005 Validationloss: 372678.875 KL divergence: 0.000 \n',
#  '(epoch: 218, iters: 8) Modelloss: 376022.281 Dataloss: 0.004 Validationloss: 374309.812 KL divergence: 0.000 \n',
#  '(epoch: 219, iters: 8) Modelloss: 377966.094 Dataloss: 0.005 Validationloss: 378169.281 KL divergence: 0.000 \n',
#  '(epoch: 220, iters: 8) Modelloss: 379335.656 Dataloss: 0.005 Validationloss: 381762.500 KL divergence: 0.000 \n',
#  '(epoch: 221, iters: 8) Modelloss: 377412.281 Dataloss: 0.005 Validationloss: 382331.781 KL divergence: 0.000 \n',
#  '(epoch: 222, iters: 8) Modelloss: 377851.312 Dataloss: 0.005 Validationloss: 375948.562 KL divergence: 0.000 \n',
#  '(epoch: 223, iters: 8) Modelloss: 376499.969 Dataloss: 0.005 Validationloss: 372854.812 KL divergence: 0.000 \n',
#  '(epoch: 224, iters: 8) Modelloss: 373926.938 Dataloss: 0.005 Validationloss: 374114.156 KL divergence: 0.000 \n',
#  '(epoch: 225, iters: 8) Modelloss: 374427.656 Dataloss: 0.005 Validationloss: 381557.781 KL divergence: 0.000 \n',
#  '(epoch: 226, iters: 8) Modelloss: 378658.031 Dataloss: 0.004 Validationloss: 382157.000 KL divergence: 0.000 \n',
#  '(epoch: 227, iters: 8) Modelloss: 375250.000 Dataloss: 0.004 Validationloss: 381603.156 KL divergence: 0.000 \n',
#  '(epoch: 228, iters: 8) Modelloss: 372111.188 Dataloss: 0.005 Validationloss: 380630.812 KL divergence: 0.000 \n',
#  '(epoch: 229, iters: 8) Modelloss: 375108.875 Dataloss: 0.004 Validationloss: 376180.812 KL divergence: 0.000 \n',
#  '(epoch: 230, iters: 8) Modelloss: 377403.875 Dataloss: 0.005 Validationloss: 375306.594 KL divergence: 0.000 \n',
#  '(epoch: 231, iters: 8) Modelloss: 372905.844 Dataloss: 0.005 Validationloss: 378448.219 KL divergence: 0.000 \n',
#  '(epoch: 232, iters: 8) Modelloss: 371004.125 Dataloss: 0.005 Validationloss: 374990.469 KL divergence: 0.000 \n',
#  '(epoch: 233, iters: 8) Modelloss: 375409.562 Dataloss: 0.004 Validationloss: 375220.906 KL divergence: 0.000 \n',
#  '(epoch: 234, iters: 8) Modelloss: 375491.594 Dataloss: 0.004 Validationloss: 378198.625 KL divergence: 0.000 \n',
#  '(epoch: 235, iters: 8) Modelloss: 373111.281 Dataloss: 0.005 Validationloss: 376819.469 KL divergence: 0.000 \n',
#  '(epoch: 236, iters: 8) Modelloss: 373001.688 Dataloss: 0.005 Validationloss: 375621.031 KL divergence: 0.000 \n',
#  '(epoch: 237, iters: 8) Modelloss: 371780.625 Dataloss: 0.004 Validationloss: 369643.031 KL divergence: 0.000 \n',
#  '(epoch: 238, iters: 8) Modelloss: 369590.688 Dataloss: 0.004 Validationloss: 369867.969 KL divergence: 0.000 \n',
#  '(epoch: 239, iters: 8) Modelloss: 370329.844 Dataloss: 0.005 Validationloss: 373847.000 KL divergence: 0.000 \n',
#  '(epoch: 240, iters: 8) Modelloss: 372963.469 Dataloss: 0.005 Validationloss: 373229.188 KL divergence: 0.000 \n',
#  '(epoch: 241, iters: 8) Modelloss: 373850.844 Dataloss: 0.004 Validationloss: 375400.438 KL divergence: 0.000 \n',
#  '(epoch: 242, iters: 8) Modelloss: 371387.125 Dataloss: 0.004 Validationloss: 375566.719 KL divergence: 0.000 \n',
#  '(epoch: 243, iters: 8) Modelloss: 370180.438 Dataloss: 0.005 Validationloss: 370891.875 KL divergence: 0.000 \n',
#  '(epoch: 244, iters: 8) Modelloss: 371246.875 Dataloss: 0.006 Validationloss: 371326.781 KL divergence: 0.000 \n',
#  '(epoch: 245, iters: 8) Modelloss: 371074.875 Dataloss: 0.004 Validationloss: 367593.344 KL divergence: 0.000 \n',
#  '(epoch: 246, iters: 8) Modelloss: 369994.125 Dataloss: 0.005 Validationloss: 369663.250 KL divergence: 0.000 \n',
#  '(epoch: 247, iters: 8) Modelloss: 371832.656 Dataloss: 0.004 Validationloss: 375910.000 KL divergence: 0.000 \n',
#  '(epoch: 248, iters: 8) Modelloss: 373289.000 Dataloss: 0.004 Validationloss: 371655.594 KL divergence: 0.000 \n',
#  '(epoch: 249, iters: 8) Modelloss: 371141.781 Dataloss: 0.005 Validationloss: 364839.312 KL divergence: 0.000 \n',
#  '(epoch: 250, iters: 8) Modelloss: 368666.625 Dataloss: 0.004 Validationloss: 365899.062 KL divergence: 0.000 \n',
#  '(epoch: 251, iters: 8) Modelloss: 371201.344 Dataloss: 0.004 Validationloss: 367787.562 KL divergence: 0.000 \n',
#  '(epoch: 252, iters: 8) Modelloss: 373763.156 Dataloss: 0.004 Validationloss: 374676.688 KL divergence: 0.000 \n',
#  '(epoch: 253, iters: 8) Modelloss: 372353.094 Dataloss: 0.005 Validationloss: 379673.125 KL divergence: 0.000 \n',
#  '(epoch: 254, iters: 8) Modelloss: 370195.625 Dataloss: 0.004 Validationloss: 370565.969 KL divergence: 0.000 \n',
#  '(epoch: 255, iters: 8) Modelloss: 369624.469 Dataloss: 0.004 Validationloss: 362439.344 KL divergence: 0.000 \n',
#  '(epoch: 256, iters: 8) Modelloss: 368946.750 Dataloss: 0.005 Validationloss: 363159.344 KL divergence: 0.000 \n',
#  '(epoch: 257, iters: 8) Modelloss: 370923.031 Dataloss: 0.005 Validationloss: 365286.375 KL divergence: 0.000 \n',
#  '(epoch: 258, iters: 8) Modelloss: 370963.500 Dataloss: 0.004 Validationloss: 369935.844 KL divergence: 0.000 \n',
#  '(epoch: 259, iters: 8) Modelloss: 371430.062 Dataloss: 0.004 Validationloss: 372941.625 KL divergence: 0.000 \n',
#  '(epoch: 260, iters: 8) Modelloss: 369976.125 Dataloss: 0.005 Validationloss: 371307.406 KL divergence: 0.000 \n',
#  '(epoch: 261, iters: 8) Modelloss: 369040.500 Dataloss: 0.005 Validationloss: 371298.750 KL divergence: 0.000 \n',
#  '(epoch: 262, iters: 8) Modelloss: 367382.875 Dataloss: 0.004 Validationloss: 366993.094 KL divergence: 0.000 \n',
#  '(epoch: 263, iters: 8) Modelloss: 366343.312 Dataloss: 0.004 Validationloss: 365246.250 KL divergence: 0.000 \n',
#  '(epoch: 264, iters: 8) Modelloss: 366654.469 Dataloss: 0.005 Validationloss: 368197.500 KL divergence: 0.000 \n',
#  '(epoch: 265, iters: 8) Modelloss: 367351.562 Dataloss: 0.004 Validationloss: 368564.500 KL divergence: 0.000 \n',
#  '(epoch: 266, iters: 8) Modelloss: 369151.375 Dataloss: 0.004 Validationloss: 371030.625 KL divergence: 0.000 \n',
#  '(epoch: 267, iters: 8) Modelloss: 371226.969 Dataloss: 0.004 Validationloss: 368546.812 KL divergence: 0.000 \n',
#  '(epoch: 268, iters: 8) Modelloss: 370403.688 Dataloss: 0.005 Validationloss: 366535.094 KL divergence: 0.000 \n',
#  '(epoch: 269, iters: 8) Modelloss: 369262.531 Dataloss: 0.004 Validationloss: 367936.875 KL divergence: 0.000 \n',
#  '(epoch: 270, iters: 8) Modelloss: 367346.312 Dataloss: 0.005 Validationloss: 369448.406 KL divergence: 0.000 \n',
#  '(epoch: 271, iters: 8) Modelloss: 366996.250 Dataloss: 0.005 Validationloss: 366445.875 KL divergence: 0.000 \n',
#  '(epoch: 272, iters: 8) Modelloss: 367751.344 Dataloss: 0.004 Validationloss: 367029.156 KL divergence: 0.000 \n',
#  '(epoch: 273, iters: 8) Modelloss: 365464.188 Dataloss: 0.005 Validationloss: 369217.250 KL divergence: 0.000 \n',
#  '(epoch: 274, iters: 8) Modelloss: 368643.969 Dataloss: 0.005 Validationloss: 367000.844 KL divergence: 0.000 \n',
#  '(epoch: 275, iters: 8) Modelloss: 373603.656 Dataloss: 0.004 Validationloss: 367778.062 KL divergence: 0.000 \n',
#  '(epoch: 276, iters: 8) Modelloss: 370845.594 Dataloss: 0.005 Validationloss: 372170.906 KL divergence: 0.000 \n',
#  '(epoch: 277, iters: 8) Modelloss: 364640.000 Dataloss: 0.005 Validationloss: 369144.500 KL divergence: 0.000 \n',
#  '(epoch: 278, iters: 8) Modelloss: 363426.844 Dataloss: 0.004 Validationloss: 360322.312 KL divergence: 0.000 \n',
#  '(epoch: 279, iters: 8) Modelloss: 368042.875 Dataloss: 0.005 Validationloss: 359454.906 KL divergence: 0.000 \n',
#  '(epoch: 280, iters: 8) Modelloss: 368569.562 Dataloss: 0.005 Validationloss: 364622.719 KL divergence: 0.000 \n',
#  '(epoch: 281, iters: 8) Modelloss: 365826.531 Dataloss: 0.005 Validationloss: 366692.125 KL divergence: 0.000 \n',
#  '(epoch: 282, iters: 8) Modelloss: 366192.406 Dataloss: 0.004 Validationloss: 370910.062 KL divergence: 0.000 \n',
#  '(epoch: 283, iters: 8) Modelloss: 367273.531 Dataloss: 0.005 Validationloss: 371934.000 KL divergence: 0.000 \n',
#  '(epoch: 284, iters: 8) Modelloss: 364303.625 Dataloss: 0.004 Validationloss: 370266.500 KL divergence: 0.000 \n',
#  '(epoch: 285, iters: 8) Modelloss: 364692.500 Dataloss: 0.005 Validationloss: 366602.562 KL divergence: 0.000 \n',
#  '(epoch: 286, iters: 8) Modelloss: 368761.656 Dataloss: 0.005 Validationloss: 368702.844 KL divergence: 0.000 \n',
#  '(epoch: 287, iters: 8) Modelloss: 368317.156 Dataloss: 0.004 Validationloss: 370088.719 KL divergence: 0.000 \n',
#  '(epoch: 288, iters: 8) Modelloss: 366256.688 Dataloss: 0.005 Validationloss: 366774.688 KL divergence: 0.000 \n',
#  '(epoch: 289, iters: 8) Modelloss: 368382.906 Dataloss: 0.005 Validationloss: 364893.281 KL divergence: 0.000 \n',
#  '(epoch: 290, iters: 8) Modelloss: 370099.281 Dataloss: 0.004 Validationloss: 359985.281 KL divergence: 0.000 \n',
#  '(epoch: 291, iters: 8) Modelloss: 365244.906 Dataloss: 0.004 Validationloss: 360495.625 KL divergence: 0.000 \n',
#  '(epoch: 292, iters: 8) Modelloss: 363400.125 Dataloss: 0.004 Validationloss: 362248.750 KL divergence: 0.000 \n',
#  '(epoch: 293, iters: 8) Modelloss: 366996.062 Dataloss: 0.004 Validationloss: 360748.000 KL divergence: 0.000 \n',
#  '(epoch: 294, iters: 8) Modelloss: 365362.094 Dataloss: 0.004 Validationloss: 362673.219 KL divergence: 0.000 \n',
#  '(epoch: 295, iters: 8) Modelloss: 361953.469 Dataloss: 0.005 Validationloss: 363835.719 KL divergence: 0.000 \n',
#  '(epoch: 296, iters: 8) Modelloss: 363533.469 Dataloss: 0.004 Validationloss: 366671.531 KL divergence: 0.000 \n',
#  '(epoch: 297, iters: 8) Modelloss: 365959.406 Dataloss: 0.005 Validationloss: 364180.156 KL divergence: 0.000 \n',
#  '(epoch: 298, iters: 8) Modelloss: 363643.062 Dataloss: 0.004 Validationloss: 365210.938 KL divergence: 0.000 \n',
#  '(epoch: 299, iters: 8) Modelloss: 361597.469 Dataloss: 0.004 Validationloss: 365154.125 KL divergence: 0.000 \n',
#  '(epoch: 300, iters: 8) Modelloss: 363358.969 Dataloss: 0.004 Validationloss: 364850.031 KL divergence: 0.000 \n',
#  '(epoch: 301, iters: 8) Modelloss: 364735.344 Dataloss: 0.004 Validationloss: 366677.969 KL divergence: 0.000 \n',
#  '(epoch: 302, iters: 8) Modelloss: 365039.375 Dataloss: 0.005 Validationloss: 364455.594 KL divergence: 0.000 \n',
#  '(epoch: 303, iters: 8) Modelloss: 365135.875 Dataloss: 0.004 Validationloss: 362856.688 KL divergence: 0.000 \n',
#  '(epoch: 304, iters: 8) Modelloss: 364398.156 Dataloss: 0.004 Validationloss: 360950.625 KL divergence: 0.000 \n',
#  '(epoch: 305, iters: 8) Modelloss: 361827.406 Dataloss: 0.005 Validationloss: 361494.781 KL divergence: 0.000 \n',
#  '(epoch: 306, iters: 8) Modelloss: 362339.656 Dataloss: 0.005 Validationloss: 366471.688 KL divergence: 0.000 \n',
#  '(epoch: 307, iters: 8) Modelloss: 364314.031 Dataloss: 0.004 Validationloss: 366617.750 KL divergence: 0.000 \n',
#  '(epoch: 308, iters: 8) Modelloss: 365040.188 Dataloss: 0.005 Validationloss: 365038.812 KL divergence: 0.000 \n',
#  '(epoch: 309, iters: 8) Modelloss: 365786.406 Dataloss: 0.005 Validationloss: 367648.000 KL divergence: 0.000 \n',
#  '(epoch: 310, iters: 8) Modelloss: 364615.969 Dataloss: 0.005 Validationloss: 363382.656 KL divergence: 0.000 \n',
#  '(epoch: 311, iters: 8) Modelloss: 362396.500 Dataloss: 0.005 Validationloss: 358039.500 KL divergence: 0.000 \n',
#  '(epoch: 312, iters: 8) Modelloss: 362660.531 Dataloss: 0.004 Validationloss: 355692.438 KL divergence: 0.000 \n',
#  '(epoch: 313, iters: 8) Modelloss: 362224.875 Dataloss: 0.004 Validationloss: 354814.562 KL divergence: 0.000 \n',
#  '(epoch: 314, iters: 8) Modelloss: 361228.812 Dataloss: 0.005 Validationloss: 358224.719 KL divergence: 0.000 \n',
#  '(epoch: 315, iters: 8) Modelloss: 364319.000 Dataloss: 0.005 Validationloss: 364005.844 KL divergence: 0.000 \n',
#  '(epoch: 316, iters: 8) Modelloss: 367323.156 Dataloss: 0.005 Validationloss: 369487.656 KL divergence: 0.000 \n',
#  '(epoch: 317, iters: 8) Modelloss: 364309.000 Dataloss: 0.005 Validationloss: 363636.812 KL divergence: 0.000 \n',
#  '(epoch: 318, iters: 8) Modelloss: 360047.438 Dataloss: 0.005 Validationloss: 354859.781 KL divergence: 0.000 \n',
#  '(epoch: 319, iters: 8) Modelloss: 358943.875 Dataloss: 0.004 Validationloss: 351132.438 KL divergence: 0.000 \n',
#  '(epoch: 320, iters: 8) Modelloss: 361398.281 Dataloss: 0.006 Validationloss: 353320.406 KL divergence: 0.000 \n',
#  '(epoch: 321, iters: 8) Modelloss: 362533.969 Dataloss: 0.005 Validationloss: 356956.094 KL divergence: 0.000 \n',
#  '(epoch: 322, iters: 8) Modelloss: 363454.344 Dataloss: 0.005 Validationloss: 363270.500 KL divergence: 0.000 \n',
#  '(epoch: 323, iters: 8) Modelloss: 365912.250 Dataloss: 0.005 Validationloss: 369140.375 KL divergence: 0.000 \n',
#  '(epoch: 324, iters: 8) Modelloss: 364620.281 Dataloss: 0.005 Validationloss: 365074.031 KL divergence: 0.000 \n',
#  '(epoch: 325, iters: 8) Modelloss: 360253.094 Dataloss: 0.005 Validationloss: 355694.000 KL divergence: 0.000 \n',
#  '(epoch: 326, iters: 8) Modelloss: 359521.500 Dataloss: 0.005 Validationloss: 352088.000 KL divergence: 0.000 \n',
#  '(epoch: 327, iters: 8) Modelloss: 362289.875 Dataloss: 0.005 Validationloss: 352677.719 KL divergence: 0.000 \n',
#  '(epoch: 328, iters: 8) Modelloss: 363210.125 Dataloss: 0.005 Validationloss: 355067.781 KL divergence: 0.000 \n',
#  '(epoch: 329, iters: 8) Modelloss: 360288.562 Dataloss: 0.004 Validationloss: 359536.750 KL divergence: 0.000 \n',
#  '(epoch: 330, iters: 8) Modelloss: 362241.625 Dataloss: 0.004 Validationloss: 361202.625 KL divergence: 0.000 \n',
#  '(epoch: 331, iters: 8) Modelloss: 364684.438 Dataloss: 0.005 Validationloss: 358170.688 KL divergence: 0.000 \n',
#  '(epoch: 332, iters: 8) Modelloss: 362951.344 Dataloss: 0.004 Validationloss: 356873.594 KL divergence: 0.000 \n',
#  '(epoch: 333, iters: 8) Modelloss: 360081.844 Dataloss: 0.004 Validationloss: 354154.406 KL divergence: 0.000 \n',
#  '(epoch: 334, iters: 8) Modelloss: 358708.500 Dataloss: 0.004 Validationloss: 350781.625 KL divergence: 0.000 \n',
#  '(epoch: 335, iters: 8) Modelloss: 360504.000 Dataloss: 0.005 Validationloss: 351564.750 KL divergence: 0.000 \n',
#  '(epoch: 336, iters: 8) Modelloss: 361331.062 Dataloss: 0.004 Validationloss: 355379.312 KL divergence: 0.000 \n',
#  '(epoch: 337, iters: 8) Modelloss: 359181.594 Dataloss: 0.004 Validationloss: 363577.906 KL divergence: 0.000 \n',
#  '(epoch: 338, iters: 8) Modelloss: 362989.062 Dataloss: 0.004 Validationloss: 365228.562 KL divergence: 0.000 \n',
#  '(epoch: 339, iters: 8) Modelloss: 365203.062 Dataloss: 0.004 Validationloss: 357822.906 KL divergence: 0.000 \n',
#  '(epoch: 340, iters: 8) Modelloss: 358576.281 Dataloss: 0.004 Validationloss: 350911.094 KL divergence: 0.000 \n',
#  '(epoch: 341, iters: 8) Modelloss: 355857.688 Dataloss: 0.004 Validationloss: 351239.156 KL divergence: 0.000 \n',
#  '(epoch: 342, iters: 8) Modelloss: 359574.531 Dataloss: 0.004 Validationloss: 354559.188 KL divergence: 0.000 \n',
#  '(epoch: 343, iters: 8) Modelloss: 360541.688 Dataloss: 0.004 Validationloss: 357343.844 KL divergence: 0.000 \n',
#  '(epoch: 344, iters: 8) Modelloss: 356098.156 Dataloss: 0.004 Validationloss: 357451.406 KL divergence: 0.000 \n',
#  '(epoch: 345, iters: 8) Modelloss: 353883.594 Dataloss: 0.004 Validationloss: 353318.375 KL divergence: 0.000 \n',
#  '(epoch: 346, iters: 8) Modelloss: 356918.562 Dataloss: 0.004 Validationloss: 353082.438 KL divergence: 0.000 \n',
#  '(epoch: 347, iters: 8) Modelloss: 359842.375 Dataloss: 0.004 Validationloss: 355135.781 KL divergence: 0.000 \n',
#  '(epoch: 348, iters: 8) Modelloss: 356760.906 Dataloss: 0.004 Validationloss: 360776.281 KL divergence: 0.000 \n',
#  '(epoch: 349, iters: 8) Modelloss: 357571.750 Dataloss: 0.004 Validationloss: 359026.625 KL divergence: 0.000 \n',
#  '(epoch: 350, iters: 8) Modelloss: 358910.688 Dataloss: 0.004 Validationloss: 354795.406 KL divergence: 0.000 \n',
#  '(epoch: 351, iters: 8) Modelloss: 355767.281 Dataloss: 0.004 Validationloss: 352250.125 KL divergence: 0.000 \n',
#  '(epoch: 352, iters: 8) Modelloss: 352411.156 Dataloss: 0.004 Validationloss: 353403.750 KL divergence: 0.000 \n',
#  '(epoch: 353, iters: 8) Modelloss: 354590.906 Dataloss: 0.005 Validationloss: 357648.594 KL divergence: 0.000 \n',
#  '(epoch: 354, iters: 8) Modelloss: 358198.531 Dataloss: 0.005 Validationloss: 355671.688 KL divergence: 0.000 \n',
#  '(epoch: 355, iters: 8) Modelloss: 356593.844 Dataloss: 0.004 Validationloss: 357193.969 KL divergence: 0.000 \n',
#  '(epoch: 356, iters: 8) Modelloss: 353181.250 Dataloss: 0.004 Validationloss: 357164.250 KL divergence: 0.000 \n',
#  '(epoch: 357, iters: 8) Modelloss: 356314.281 Dataloss: 0.004 Validationloss: 353825.812 KL divergence: 0.000 \n',
#  '(epoch: 358, iters: 8) Modelloss: 360842.125 Dataloss: 0.004 Validationloss: 354998.438 KL divergence: 0.000 \n',
#  '(epoch: 359, iters: 8) Modelloss: 358559.812 Dataloss: 0.004 Validationloss: 357061.938 KL divergence: 0.000 \n',
#  '(epoch: 360, iters: 8) Modelloss: 354435.688 Dataloss: 0.004 Validationloss: 358319.125 KL divergence: 0.000 \n',
#  '(epoch: 361, iters: 8) Modelloss: 356739.375 Dataloss: 0.004 Validationloss: 357814.656 KL divergence: 0.000 \n',
#  '(epoch: 362, iters: 8) Modelloss: 359596.719 Dataloss: 0.004 Validationloss: 355388.531 KL divergence: 0.000 \n',
#  '(epoch: 363, iters: 8) Modelloss: 356018.219 Dataloss: 0.004 Validationloss: 356623.094 KL divergence: 0.000 \n',
#  '(epoch: 364, iters: 8) Modelloss: 353698.906 Dataloss: 0.004 Validationloss: 358498.406 KL divergence: 0.000 \n',
#  '(epoch: 365, iters: 8) Modelloss: 357448.812 Dataloss: 0.004 Validationloss: 358124.562 KL divergence: 0.000 \n',
#  '(epoch: 366, iters: 8) Modelloss: 356515.594 Dataloss: 0.004 Validationloss: 354573.031 KL divergence: 0.000 \n',
#  '(epoch: 367, iters: 8) Modelloss: 351826.125 Dataloss: 0.004 Validationloss: 350548.562 KL divergence: 0.000 \n',
#  '(epoch: 368, iters: 8) Modelloss: 350728.812 Dataloss: 0.004 Validationloss: 352538.688 KL divergence: 0.000 \n',
#  '(epoch: 369, iters: 8) Modelloss: 354300.500 Dataloss: 0.004 Validationloss: 351264.031 KL divergence: 0.000 \n',
#  '(epoch: 370, iters: 8) Modelloss: 355173.531 Dataloss: 0.004 Validationloss: 351876.938 KL divergence: 0.000 \n',
#  '(epoch: 371, iters: 8) Modelloss: 353762.469 Dataloss: 0.005 Validationloss: 355079.125 KL divergence: 0.000 \n',
#  '(epoch: 372, iters: 8) Modelloss: 354769.500 Dataloss: 0.004 Validationloss: 353318.031 KL divergence: 0.000 \n',
#  '(epoch: 373, iters: 8) Modelloss: 355174.688 Dataloss: 0.005 Validationloss: 352557.688 KL divergence: 0.000 \n',
#  '(epoch: 374, iters: 8) Modelloss: 352923.719 Dataloss: 0.005 Validationloss: 355112.781 KL divergence: 0.000 \n',
#  '(epoch: 375, iters: 8) Modelloss: 351295.344 Dataloss: 0.004 Validationloss: 352072.000 KL divergence: 0.000 \n',
#  '(epoch: 376, iters: 8) Modelloss: 350327.344 Dataloss: 0.005 Validationloss: 350219.500 KL divergence: 0.000 \n',
#  '(epoch: 377, iters: 8) Modelloss: 354810.938 Dataloss: 0.004 Validationloss: 352556.000 KL divergence: 0.000 \n',
#  '(epoch: 378, iters: 8) Modelloss: 358293.594 Dataloss: 0.006 Validationloss: 355111.938 KL divergence: 0.000 \n',
#  '(epoch: 379, iters: 8) Modelloss: 359262.875 Dataloss: 0.005 Validationloss: 353734.875 KL divergence: 0.000 \n',
#  '(epoch: 380, iters: 8) Modelloss: 357604.125 Dataloss: 0.007 Validationloss: 351554.969 KL divergence: 0.000 \n',
#  '(epoch: 381, iters: 8) Modelloss: 356484.094 Dataloss: 0.005 Validationloss: 352603.812 KL divergence: 0.000 \n',
#  '(epoch: 382, iters: 8) Modelloss: 355703.156 Dataloss: 0.007 Validationloss: 357097.125 KL divergence: 0.000 \n',
#  '(epoch: 383, iters: 8) Modelloss: 353940.281 Dataloss: 0.009 Validationloss: 353867.188 KL divergence: 0.000 \n',
#  '(epoch: 384, iters: 8) Modelloss: 353393.969 Dataloss: 0.005 Validationloss: 345254.844 KL divergence: 0.000 \n',
#  '(epoch: 385, iters: 8) Modelloss: 354291.312 Dataloss: 0.009 Validationloss: 339463.781 KL divergence: 0.000 \n',
#  '(epoch: 386, iters: 8) Modelloss: 356726.812 Dataloss: 0.007 Validationloss: 339575.875 KL divergence: 0.000 \n',
#  '(epoch: 387, iters: 8) Modelloss: 358272.094 Dataloss: 0.007 Validationloss: 344381.562 KL divergence: 0.000 \n',
#  '(epoch: 388, iters: 8) Modelloss: 356950.312 Dataloss: 0.008 Validationloss: 348406.781 KL divergence: 0.000 \n',
#  '(epoch: 389, iters: 8) Modelloss: 355354.469 Dataloss: 0.006 Validationloss: 350083.250 KL divergence: 0.000 \n',
#  '(epoch: 390, iters: 8) Modelloss: 355353.062 Dataloss: 0.006 Validationloss: 350201.281 KL divergence: 0.000 \n',
#  '(epoch: 391, iters: 8) Modelloss: 360593.094 Dataloss: 0.008 Validationloss: 352084.125 KL divergence: 0.000 \n',
#  '(epoch: 392, iters: 8) Modelloss: 365701.375 Dataloss: 0.006 Validationloss: 356666.656 KL divergence: 0.000 \n',
#  '(epoch: 393, iters: 8) Modelloss: 365165.875 Dataloss: 0.007 Validationloss: 363522.969 KL divergence: 0.000 \n',
#  '(epoch: 394, iters: 8) Modelloss: 361411.156 Dataloss: 0.008 Validationloss: 361933.406 KL divergence: 0.000 \n',
#  '(epoch: 395, iters: 8) Modelloss: 356519.000 Dataloss: 0.006 Validationloss: 352859.000 KL divergence: 0.000 \n',
#  '(epoch: 396, iters: 8) Modelloss: 359478.125 Dataloss: 0.006 Validationloss: 347817.438 KL divergence: 0.000 \n',
#  '(epoch: 397, iters: 8) Modelloss: 363909.125 Dataloss: 0.005 Validationloss: 346610.875 KL divergence: 0.000 \n',
#  '(epoch: 398, iters: 8) Modelloss: 361391.000 Dataloss: 0.006 Validationloss: 346566.719 KL divergence: 0.000 \n',
#  '(epoch: 399, iters: 8) Modelloss: 357965.312 Dataloss: 0.005 Validationloss: 346777.219 KL divergence: 0.000 \n',
#  '(epoch: 400, iters: 8) Modelloss: 355826.594 Dataloss: 0.006 Validationloss: 345834.781 KL divergence: 0.000 \n',
#  '(epoch: 401, iters: 8) Modelloss: 358409.500 Dataloss: 0.005 Validationloss: 348163.906 KL divergence: 0.000 \n',
#  '(epoch: 402, iters: 8) Modelloss: 362606.969 Dataloss: 0.006 Validationloss: 352297.031 KL divergence: 0.000 \n',
#  '(epoch: 403, iters: 8) Modelloss: 364070.781 Dataloss: 0.006 Validationloss: 353683.219 KL divergence: 0.000 \n',
#  '(epoch: 404, iters: 8) Modelloss: 362444.375 Dataloss: 0.005 Validationloss: 352055.750 KL divergence: 0.000 \n',
#  '(epoch: 405, iters: 8) Modelloss: 357602.156 Dataloss: 0.005 Validationloss: 352692.312 KL divergence: 0.000 \n',
#  '(epoch: 406, iters: 8) Modelloss: 356083.938 Dataloss: 0.005 Validationloss: 353785.000 KL divergence: 0.000 \n',
#  '(epoch: 407, iters: 8) Modelloss: 358184.438 Dataloss: 0.005 Validationloss: 352088.812 KL divergence: 0.000 \n',
#  '(epoch: 408, iters: 8) Modelloss: 358255.938 Dataloss: 0.005 Validationloss: 348922.438 KL divergence: 0.000 \n',
#  '(epoch: 409, iters: 8) Modelloss: 355876.844 Dataloss: 0.004 Validationloss: 350486.812 KL divergence: 0.000 \n',
#  '(epoch: 410, iters: 8) Modelloss: 354412.812 Dataloss: 0.005 Validationloss: 356603.062 KL divergence: 0.000 \n',
#  '(epoch: 411, iters: 8) Modelloss: 356008.188 Dataloss: 0.004 Validationloss: 359064.875 KL divergence: 0.000 \n',
#  '(epoch: 412, iters: 8) Modelloss: 360083.469 Dataloss: 0.004 Validationloss: 357697.438 KL divergence: 0.000 \n',
#  '(epoch: 413, iters: 8) Modelloss: 361124.969 Dataloss: 0.004 Validationloss: 356141.094 KL divergence: 0.000 \n',
# ...
#  '(epoch: 863, iters: 8) Modelloss: 317820.812 Dataloss: 0.003 Validationloss: 319738.844 KL divergence: 0.000 \n',
#  '(epoch: 864, iters: 8) Modelloss: 319689.719 Dataloss: 0.003 Validationloss: 318095.406 KL divergence: 0.000 \n',
#  '(epoch: 865, iters: 8) Modelloss: 322650.125 Dataloss: 0.003 Validationloss: 317559.125 KL divergence: 0.000 \n',
#  '(epoch: 866, iters: 8) Modelloss: 323400.688 Dataloss: 0.002 Validationloss: 320736.938 KL divergence: 0.000 \n',
#  '(epoch: 867, iters: 8) Modelloss: 321210.062 Dataloss: 0.002 Validationloss: 322878.844 KL divergence: 0.000 \n',
#  '(epoch: 868, iters: 8) Modelloss: 319384.688 Dataloss: 0.002 Validationloss: 322110.438 KL divergence: 0.000 \n',
#  '(epoch: 869, iters: 8) Modelloss: 322773.406 Dataloss: 0.002 Validationloss: 321031.438 KL divergence: 0.000 \n',
#  '(epoch: 870, iters: 8) Modelloss: 323890.750 Dataloss: 0.002 Validationloss: 319845.031 KL divergence: 0.000 \n',
#  '(epoch: 871, iters: 8) Modelloss: 321037.812 Dataloss: 0.002 Validationloss: 320086.250 KL divergence: 0.000 \n',
#  '(epoch: 872, iters: 8) Modelloss: 320576.000 Dataloss: 0.002 Validationloss: 320640.438 KL divergence: 0.000 \n',
#  '(epoch: 873, iters: 8) Modelloss: 322300.031 Dataloss: 0.002 Validationloss: 320627.344 KL divergence: 0.000 \n',
#  '(epoch: 874, iters: 8) Modelloss: 322643.406 Dataloss: 0.002 Validationloss: 322414.812 KL divergence: 0.000 \n',
#  '(epoch: 875, iters: 8) Modelloss: 321192.156 Dataloss: 0.002 Validationloss: 322751.656 KL divergence: 0.000 \n',
#  '(epoch: 876, iters: 8) Modelloss: 321126.031 Dataloss: 0.002 Validationloss: 319966.469 KL divergence: 0.000 \n',
#  '(epoch: 877, iters: 8) Modelloss: 323167.469 Dataloss: 0.002 Validationloss: 317316.625 KL divergence: 0.000 \n',
#  '(epoch: 878, iters: 8) Modelloss: 322386.312 Dataloss: 0.002 Validationloss: 315626.500 KL divergence: 0.000 \n',
#  '(epoch: 879, iters: 8) Modelloss: 318573.719 Dataloss: 0.002 Validationloss: 317260.844 KL divergence: 0.000 \n',
#  '(epoch: 880, iters: 8) Modelloss: 318725.812 Dataloss: 0.002 Validationloss: 319277.062 KL divergence: 0.000 \n',
#  '(epoch: 881, iters: 8) Modelloss: 322787.438 Dataloss: 0.002 Validationloss: 321014.562 KL divergence: 0.000 \n',
#  '(epoch: 882, iters: 8) Modelloss: 323017.000 Dataloss: 0.002 Validationloss: 323229.656 KL divergence: 0.000 \n',
#  '(epoch: 883, iters: 8) Modelloss: 320145.250 Dataloss: 0.002 Validationloss: 323202.656 KL divergence: 0.000 \n',
#  '(epoch: 884, iters: 8) Modelloss: 319263.312 Dataloss: 0.002 Validationloss: 320571.656 KL divergence: 0.000 \n',
#  '(epoch: 885, iters: 8) Modelloss: 320630.375 Dataloss: 0.002 Validationloss: 318029.219 KL divergence: 0.000 \n',
#  '(epoch: 886, iters: 8) Modelloss: 320681.781 Dataloss: 0.002 Validationloss: 317342.750 KL divergence: 0.000 \n',
#  '(epoch: 887, iters: 8) Modelloss: 319042.219 Dataloss: 0.002 Validationloss: 317613.344 KL divergence: 0.000 \n',
#  '(epoch: 888, iters: 8) Modelloss: 319871.625 Dataloss: 0.002 Validationloss: 320392.875 KL divergence: 0.000 \n',
#  '(epoch: 889, iters: 8) Modelloss: 321067.594 Dataloss: 0.002 Validationloss: 322177.062 KL divergence: 0.000 \n',
#  '(epoch: 890, iters: 8) Modelloss: 320666.938 Dataloss: 0.002 Validationloss: 323463.531 KL divergence: 0.000 \n',
#  '(epoch: 891, iters: 8) Modelloss: 319571.594 Dataloss: 0.002 Validationloss: 321699.625 KL divergence: 0.000 \n',
#  '(epoch: 892, iters: 8) Modelloss: 320596.625 Dataloss: 0.002 Validationloss: 318895.125 KL divergence: 0.000 \n',
#  '(epoch: 893, iters: 8) Modelloss: 321045.750 Dataloss: 0.002 Validationloss: 318502.781 KL divergence: 0.000 \n',
#  '(epoch: 894, iters: 8) Modelloss: 320097.969 Dataloss: 0.002 Validationloss: 318605.812 KL divergence: 0.000 \n',
#  '(epoch: 895, iters: 8) Modelloss: 319484.969 Dataloss: 0.002 Validationloss: 318123.625 KL divergence: 0.000 \n',
#  '(epoch: 896, iters: 8) Modelloss: 318440.438 Dataloss: 0.002 Validationloss: 315920.250 KL divergence: 0.000 \n',
#  '(epoch: 897, iters: 8) Modelloss: 318497.719 Dataloss: 0.002 Validationloss: 315505.906 KL divergence: 0.000 \n',
#  '(epoch: 898, iters: 8) Modelloss: 318428.594 Dataloss: 0.002 Validationloss: 315471.781 KL divergence: 0.000 \n',
#  '(epoch: 899, iters: 8) Modelloss: 317823.406 Dataloss: 0.002 Validationloss: 317254.312 KL divergence: 0.000 \n',
#  '(epoch: 900, iters: 8) Modelloss: 319322.250 Dataloss: 0.002 Validationloss: 318354.000 KL divergence: 0.000 \n',
#  '(epoch: 901, iters: 8) Modelloss: 319047.062 Dataloss: 0.002 Validationloss: 318290.844 KL divergence: 0.000 \n',
#  '(epoch: 902, iters: 8) Modelloss: 318321.906 Dataloss: 0.002 Validationloss: 318358.875 KL divergence: 0.000 \n',
#  '(epoch: 903, iters: 8) Modelloss: 317689.781 Dataloss: 0.002 Validationloss: 315877.219 KL divergence: 0.000 \n',
#  '(epoch: 904, iters: 8) Modelloss: 318414.469 Dataloss: 0.002 Validationloss: 315907.594 KL divergence: 0.000 \n',
#  '(epoch: 905, iters: 8) Modelloss: 317841.719 Dataloss: 0.002 Validationloss: 317282.781 KL divergence: 0.000 \n',
#  '(epoch: 906, iters: 8) Modelloss: 317379.344 Dataloss: 0.002 Validationloss: 319545.688 KL divergence: 0.000 \n',
#  '(epoch: 907, iters: 8) Modelloss: 319275.938 Dataloss: 0.002 Validationloss: 318495.562 KL divergence: 0.000 \n',
#  '(epoch: 908, iters: 8) Modelloss: 318876.719 Dataloss: 0.002 Validationloss: 317483.656 KL divergence: 0.000 \n',
#  '(epoch: 909, iters: 8) Modelloss: 317209.469 Dataloss: 0.002 Validationloss: 315641.438 KL divergence: 0.000 \n',
#  '(epoch: 910, iters: 8) Modelloss: 317592.781 Dataloss: 0.002 Validationloss: 315895.469 KL divergence: 0.000 \n',
#  '(epoch: 911, iters: 8) Modelloss: 317696.406 Dataloss: 0.002 Validationloss: 315495.750 KL divergence: 0.000 \n',
#  '(epoch: 912, iters: 8) Modelloss: 316934.000 Dataloss: 0.002 Validationloss: 315060.094 KL divergence: 0.000 \n',
#  '(epoch: 913, iters: 8) Modelloss: 316966.625 Dataloss: 0.002 Validationloss: 316138.500 KL divergence: 0.000 \n',
#  '(epoch: 914, iters: 8) Modelloss: 316811.500 Dataloss: 0.002 Validationloss: 316920.062 KL divergence: 0.000 \n',
#  '(epoch: 915, iters: 8) Modelloss: 317323.625 Dataloss: 0.002 Validationloss: 318928.312 KL divergence: 0.000 \n',
#  '(epoch: 916, iters: 8) Modelloss: 317198.531 Dataloss: 0.002 Validationloss: 317091.094 KL divergence: 0.000 \n',
#  '(epoch: 917, iters: 8) Modelloss: 316470.250 Dataloss: 0.002 Validationloss: 315128.312 KL divergence: 0.000 \n',
#  '(epoch: 918, iters: 8) Modelloss: 315895.188 Dataloss: 0.002 Validationloss: 313448.969 KL divergence: 0.000 \n',
#  '(epoch: 919, iters: 8) Modelloss: 316848.469 Dataloss: 0.002 Validationloss: 313559.469 KL divergence: 0.000 \n',
#  '(epoch: 920, iters: 8) Modelloss: 316794.938 Dataloss: 0.002 Validationloss: 313276.781 KL divergence: 0.000 \n',
#  '(epoch: 921, iters: 8) Modelloss: 315237.781 Dataloss: 0.002 Validationloss: 315159.594 KL divergence: 0.000 \n',
#  '(epoch: 922, iters: 8) Modelloss: 315688.219 Dataloss: 0.001 Validationloss: 315692.094 KL divergence: 0.000 \n',
#  '(epoch: 923, iters: 8) Modelloss: 317031.531 Dataloss: 0.002 Validationloss: 316430.875 KL divergence: 0.000 \n',
#  '(epoch: 924, iters: 8) Modelloss: 315335.031 Dataloss: 0.002 Validationloss: 316352.844 KL divergence: 0.000 \n',
#  '(epoch: 925, iters: 8) Modelloss: 315616.656 Dataloss: 0.002 Validationloss: 317641.938 KL divergence: 0.000 \n',
#  '(epoch: 926, iters: 8) Modelloss: 316857.531 Dataloss: 0.002 Validationloss: 317030.125 KL divergence: 0.000 \n',
#  '(epoch: 927, iters: 8) Modelloss: 316655.781 Dataloss: 0.002 Validationloss: 316854.531 KL divergence: 0.000 \n',
#  '(epoch: 928, iters: 8) Modelloss: 314495.406 Dataloss: 0.002 Validationloss: 314447.406 KL divergence: 0.000 \n',
#  '(epoch: 929, iters: 8) Modelloss: 315741.719 Dataloss: 0.002 Validationloss: 312951.125 KL divergence: 0.000 \n',
#  '(epoch: 930, iters: 8) Modelloss: 316324.938 Dataloss: 0.002 Validationloss: 313263.938 KL divergence: 0.000 \n',
#  '(epoch: 931, iters: 8) Modelloss: 314518.938 Dataloss: 0.002 Validationloss: 315360.219 KL divergence: 0.000 \n',
#  '(epoch: 932, iters: 8) Modelloss: 314228.844 Dataloss: 0.002 Validationloss: 315886.156 KL divergence: 0.000 \n',
#  '(epoch: 933, iters: 8) Modelloss: 316080.906 Dataloss: 0.002 Validationloss: 315685.906 KL divergence: 0.000 \n',
#  '(epoch: 934, iters: 8) Modelloss: 314937.750 Dataloss: 0.002 Validationloss: 312965.594 KL divergence: 0.000 \n',
#  '(epoch: 935, iters: 8) Modelloss: 313116.656 Dataloss: 0.002 Validationloss: 310999.906 KL divergence: 0.000 \n',
#  '(epoch: 936, iters: 8) Modelloss: 315455.875 Dataloss: 0.002 Validationloss: 311223.938 KL divergence: 0.000 \n',
#  '(epoch: 937, iters: 8) Modelloss: 316548.031 Dataloss: 0.002 Validationloss: 312665.094 KL divergence: 0.000 \n',
#  '(epoch: 938, iters: 8) Modelloss: 313798.688 Dataloss: 0.002 Validationloss: 315927.250 KL divergence: 0.000 \n',
#  '(epoch: 939, iters: 8) Modelloss: 312913.094 Dataloss: 0.002 Validationloss: 314165.562 KL divergence: 0.000 \n',
#  '(epoch: 940, iters: 8) Modelloss: 314380.469 Dataloss: 0.002 Validationloss: 313823.000 KL divergence: 0.000 \n',
#  '(epoch: 941, iters: 8) Modelloss: 314278.500 Dataloss: 0.002 Validationloss: 313525.156 KL divergence: 0.000 \n',
#  '(epoch: 942, iters: 8) Modelloss: 312834.906 Dataloss: 0.002 Validationloss: 313721.406 KL divergence: 0.000 \n',
#  '(epoch: 943, iters: 8) Modelloss: 314639.906 Dataloss: 0.002 Validationloss: 312560.250 KL divergence: 0.000 \n',
#  '(epoch: 944, iters: 8) Modelloss: 315129.719 Dataloss: 0.002 Validationloss: 311955.781 KL divergence: 0.000 \n',
#  '(epoch: 945, iters: 8) Modelloss: 311778.250 Dataloss: 0.002 Validationloss: 313507.250 KL divergence: 0.000 \n',
#  '(epoch: 946, iters: 8) Modelloss: 310954.469 Dataloss: 0.002 Validationloss: 313415.625 KL divergence: 0.000 \n',
#  '(epoch: 947, iters: 8) Modelloss: 314542.938 Dataloss: 0.002 Validationloss: 314836.281 KL divergence: 0.000 \n',
#  '(epoch: 948, iters: 8) Modelloss: 315399.500 Dataloss: 0.002 Validationloss: 316118.062 KL divergence: 0.000 \n',
#  '(epoch: 949, iters: 8) Modelloss: 313969.156 Dataloss: 0.003 Validationloss: 314046.875 KL divergence: 0.000 \n',
#  '(epoch: 950, iters: 8) Modelloss: 313354.156 Dataloss: 0.002 Validationloss: 313466.062 KL divergence: 0.000 \n',
#  '(epoch: 951, iters: 8) Modelloss: 313371.438 Dataloss: 0.002 Validationloss: 313309.875 KL divergence: 0.000 \n',
#  '(epoch: 952, iters: 8) Modelloss: 313218.406 Dataloss: 0.003 Validationloss: 313742.938 KL divergence: 0.000 \n',
#  '(epoch: 953, iters: 8) Modelloss: 312435.594 Dataloss: 0.002 Validationloss: 315571.500 KL divergence: 0.000 \n',
#  '(epoch: 954, iters: 8) Modelloss: 312319.906 Dataloss: 0.002 Validationloss: 316201.094 KL divergence: 0.000 \n',
#  '(epoch: 955, iters: 8) Modelloss: 313335.312 Dataloss: 0.002 Validationloss: 312995.938 KL divergence: 0.000 \n',
#  '(epoch: 956, iters: 8) Modelloss: 314469.969 Dataloss: 0.002 Validationloss: 310946.812 KL divergence: 0.000 \n',
#  '(epoch: 957, iters: 8) Modelloss: 312383.906 Dataloss: 0.002 Validationloss: 310279.250 KL divergence: 0.000 \n',
#  '(epoch: 958, iters: 8) Modelloss: 312008.500 Dataloss: 0.002 Validationloss: 310845.438 KL divergence: 0.000 \n',
#  '(epoch: 959, iters: 8) Modelloss: 313971.344 Dataloss: 0.003 Validationloss: 314902.094 KL divergence: 0.000 \n',
#  '(epoch: 960, iters: 8) Modelloss: 314913.531 Dataloss: 0.002 Validationloss: 315820.500 KL divergence: 0.000 \n',
#  '(epoch: 961, iters: 8) Modelloss: 313294.344 Dataloss: 0.002 Validationloss: 313508.219 KL divergence: 0.000 \n',
#  '(epoch: 962, iters: 8) Modelloss: 312902.031 Dataloss: 0.003 Validationloss: 311410.500 KL divergence: 0.000 \n',
#  '(epoch: 963, iters: 8) Modelloss: 312541.438 Dataloss: 0.002 Validationloss: 309142.344 KL divergence: 0.000 \n',
#  '(epoch: 964, iters: 8) Modelloss: 312745.125 Dataloss: 0.002 Validationloss: 310990.062 KL divergence: 0.000 \n',
#  '(epoch: 965, iters: 8) Modelloss: 314083.562 Dataloss: 0.002 Validationloss: 314887.375 KL divergence: 0.000 \n',
#  '(epoch: 966, iters: 8) Modelloss: 314307.719 Dataloss: 0.002 Validationloss: 315976.062 KL divergence: 0.000 \n',
#  '(epoch: 967, iters: 8) Modelloss: 314096.000 Dataloss: 0.002 Validationloss: 313590.844 KL divergence: 0.000 \n',
#  '(epoch: 968, iters: 8) Modelloss: 313141.156 Dataloss: 0.002 Validationloss: 312227.344 KL divergence: 0.000 \n',
#  '(epoch: 969, iters: 8) Modelloss: 312082.781 Dataloss: 0.002 Validationloss: 310784.188 KL divergence: 0.000 \n',
#  '(epoch: 970, iters: 8) Modelloss: 314039.312 Dataloss: 0.002 Validationloss: 312498.000 KL divergence: 0.000 \n',
#  '(epoch: 971, iters: 8) Modelloss: 314865.062 Dataloss: 0.002 Validationloss: 312753.875 KL divergence: 0.000 \n',
#  '(epoch: 972, iters: 8) Modelloss: 312294.906 Dataloss: 0.002 Validationloss: 311243.719 KL divergence: 0.000 \n',
#  '(epoch: 973, iters: 8) Modelloss: 311446.375 Dataloss: 0.002 Validationloss: 310468.406 KL divergence: 0.000 \n',
#  '(epoch: 974, iters: 8) Modelloss: 312543.031 Dataloss: 0.002 Validationloss: 310268.281 KL divergence: 0.000 \n',
#  '(epoch: 975, iters: 8) Modelloss: 314234.750 Dataloss: 0.003 Validationloss: 310995.188 KL divergence: 0.000 \n',
#  '(epoch: 976, iters: 8) Modelloss: 314757.500 Dataloss: 0.002 Validationloss: 313246.469 KL divergence: 0.000 \n',
#  '(epoch: 977, iters: 8) Modelloss: 313494.094 Dataloss: 0.002 Validationloss: 313440.281 KL divergence: 0.000 \n',
#  '(epoch: 978, iters: 8) Modelloss: 313580.219 Dataloss: 0.002 Validationloss: 311858.844 KL divergence: 0.000 \n',
#  '(epoch: 979, iters: 8) Modelloss: 314237.312 Dataloss: 0.002 Validationloss: 310931.438 KL divergence: 0.000 \n',
#  '(epoch: 980, iters: 8) Modelloss: 312148.625 Dataloss: 0.002 Validationloss: 310394.312 KL divergence: 0.000 \n',
#  '(epoch: 981, iters: 8) Modelloss: 309543.031 Dataloss: 0.002 Validationloss: 310301.156 KL divergence: 0.000 \n',
#  '(epoch: 982, iters: 8) Modelloss: 310245.969 Dataloss: 0.002 Validationloss: 310691.906 KL divergence: 0.000 \n',
#  '(epoch: 983, iters: 8) Modelloss: 313191.750 Dataloss: 0.002 Validationloss: 312117.438 KL divergence: 0.000 \n',
#  '(epoch: 984, iters: 8) Modelloss: 313658.438 Dataloss: 0.002 Validationloss: 313661.688 KL divergence: 0.000 \n',
#  '(epoch: 985, iters: 8) Modelloss: 312489.250 Dataloss: 0.002 Validationloss: 314315.688 KL divergence: 0.000 \n',
#  '(epoch: 986, iters: 8) Modelloss: 313154.125 Dataloss: 0.002 Validationloss: 312888.344 KL divergence: 0.000 \n',
#  '(epoch: 987, iters: 8) Modelloss: 312761.062 Dataloss: 0.002 Validationloss: 312360.219 KL divergence: 0.000 \n',
#  '(epoch: 988, iters: 8) Modelloss: 310345.969 Dataloss: 0.002 Validationloss: 311526.750 KL divergence: 0.000 \n',
#  '(epoch: 989, iters: 8) Modelloss: 310869.938 Dataloss: 0.002 Validationloss: 312256.625 KL divergence: 0.000 \n',
#  '(epoch: 990, iters: 8) Modelloss: 311473.188 Dataloss: 0.002 Validationloss: 312873.625 KL divergence: 0.000 \n',
#  '(epoch: 991, iters: 8) Modelloss: 311609.938 Dataloss: 0.002 Validationloss: 314113.281 KL divergence: 0.000 \n',
#  '(epoch: 992, iters: 8) Modelloss: 311454.531 Dataloss: 0.002 Validationloss: 311726.094 KL divergence: 0.000 \n',
#  '(epoch: 993, iters: 8) Modelloss: 312124.719 Dataloss: 0.002 Validationloss: 310599.094 KL divergence: 0.000 \n',
#  '(epoch: 994, iters: 8) Modelloss: 311306.438 Dataloss: 0.002 Validationloss: 308328.500 KL divergence: 0.000 \n',
#  '(epoch: 995, iters: 8) Modelloss: 311193.250 Dataloss: 0.002 Validationloss: 310374.562 KL divergence: 0.000 \n',
#  '(epoch: 996, iters: 8) Modelloss: 311237.500 Dataloss: 0.001 Validationloss: 311890.031 KL divergence: 0.000 \n',
#  '(epoch: 997, iters: 8) Modelloss: 312303.281 Dataloss: 0.002 Validationloss: 313688.875 KL divergence: 0.000 \n',
#  '(epoch: 998, iters: 8) Modelloss: 310538.562 Dataloss: 0.002 Validationloss: 311643.062 KL divergence: 0.000 \n',
#  '(epoch: 999, iters: 8) Modelloss: 309980.188 Dataloss: 0.002 Validationloss: 309948.906 KL divergence: 0.000 \n',
#  ...]

# %%
with open('/disk/student/adhara/Fall2021/PhysicsBasedFWI/checkpoints/marmousiconvergence/loss_log.txt') as f:
    lines = f.readlines()
epochs = []
mls = []
vls = []
kls = []
dls = []
for i in range(1,len(lines)):
    #print("i:",i)
    po = lines[i].split(')')
    string1 = po[0][1:]
    string2 = po[1]
    result1 = dict((a.strip(), int(b.strip()))  
                         for a, b in (element.split(':')  
                                      for element in string1.split(', ')))  
    epoch = int(result1['epoch'])
    result2 = string2.split(' ')
    modelloss = float(result2[2])
    validationloss = float(result2[6])
    klloss = float(result2[9])
    dlloss = float(result2[4])
    epochs = np.append(epochs,epoch)
    mls = np.append(mls,modelloss)
    vls = np.append(vls,validationloss)
    kls = np.append(kls,klloss)
    dls = np.append(dls,dlloss)

# %%
#plt.plot(epochs,mls)
plt.figure(figsize=(12, 3))
plt.plot(epochs,mls/np.max(mls),linewidth=3.0)
plt.xlabel("iteration")
plt.ylabel("model loss : normalized error")
#plt.plot(epochs,kls/np.max(kls),linewidth=3.0)
#plt.plot(epochs,vls/np.max(vls),linewidth=3.0)
plt.grid()

# %%
#plt.plot(epochs,mls)
plt.figure(figsize=(12, 3))
plt.plot(epochs,dls/np.max(dls),linewidth=3.0)
plt.xlabel("iteration")
plt.ylabel("data loss : normalized error")
#plt.plot(epochs,kls/np.max(kls),linewidth=3.0)
#plt.plot(epochs,vls/np.max(vls),linewidth=3.0)
plt.grid()

# %%
rows = 3
columns = 3
fig1 = plt.figure(figsize=(12,9))

#plt.subplots_adjust(left=0.05, right=0.95, top=0.1)
max1 = np.max(inverted/1000)
min1 = np.min(inverted/1000)

ax = fig1.add_subplot(rows,columns,1)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeAD0ep10.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 10")


ax = fig1.add_subplot(rows,columns,2)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeAD0ep200.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 500")

ax = fig1.add_subplot(rows,columns,3)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeAD0ep700.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 700")

ax = fig1.add_subplot(rows,columns,4)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeAD0ep1500.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 1500")

#ax = fig1.add_subplot(rows,columns,5)
#im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeAD0ep2500.npy')
#im1 = np.squeeze(np.squeeze(im1/1000))
#im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
#ax = plt.gca(); 
#ax.set_title("iteration 2500")

ax = fig1.add_subplot(rows,columns,5)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeAD0ep3000.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 3000")

ax = fig1.add_subplot(rows,columns,6)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeNADR20ep800.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 3800")

#ax = fig1.add_subplot(rows,columns,7)
#im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeNADR20ep1600.npy')
#im1 = np.squeeze(np.squeeze(im1/1000))
#im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
#ax = plt.gca(); 
#ax.set_title("iteration 4600")

ax = fig1.add_subplot(rows,columns,7)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeNADR30ep800.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 5800")

ax = fig1.add_subplot(rows,columns,8)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeNADR30ep1200.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 6200")

ax = fig1.add_subplot(rows,columns,9)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/FakeNADR30ep1900.npy')
im1 = np.squeeze(np.squeeze(im1/1000))
im = plt.imshow(im1,'jet',**par,vmin=min1,vmax=max1)
ax = plt.gca(); 
ax.set_title("iteration 6900")

fig1.tight_layout(pad=2.0)

# %%
def plotFakeVelNewStd():
    
    #create figure
    #fig1 = plt.figure(figsize=(9,9))
    #fig2 = plt.figure(figsize=(15,15))
    
    rows = 3
    columns = 3
    matVel = np.zeros((50,1,151,200))
    for k in range(50):
        filename='/disk/student/adhara/Fall2021/FCNVMB-Deep-learning-based-seismic-velocity-model-building/Output'+str(k)+'/'    
        for i in range(1):
            #fig.add_subplot(rows,columns,i+1)
            #kk=starting+i
            onefile = filename+'150_fake_BT.npy'
            mat=np.load(onefile)
            mat = mat
            matVel[k,i,:,:] = mat
            
    mean = np.mean(matVel*1000,axis=0)
    std = np.std(matVel*1000,axis=0)
    p1 = np.percentile(matVel,5,axis=0)
    q1 = np.percentile(matVel,95,axis=0)
    mean = np.squeeze(mean)
    std = np.squeeze(std)
    p1 = np.squeeze(p1)
    q1 = np.squeeze(q1)
    
    print("mean :", np.shape(mean))
    print("std :", np.shape(std))
    print("p1 :", np.shape(p1))
    print("q1 :", np.shape(q1))
    return mean, std, p1, q1

# %%
mean,std,p1,q1 = plotFakeVelNewStd()
# Out:
# mean : (151, 200)
# std : (151, 200)
# p1 : (151, 200)
# q1 : (151, 200)

# %%
par = {'extent': [0, nx*dx/1000, nz*dx/1000, 0]}
plt.figure(figsize=(12,8))
im = plt.imshow(std,'jet',**par)
ax = plt.gca(); 
divider = make_axes_locatable(ax); cax = divider.append_axes("right", size="5%", pad=0.05); plt.colorbar(im, cax=cax, label='km/s');

# %%
inverted = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi23/FakeAD0ep1800.npy')
inverted = inverted[0,0,:,:]
plt.figure(figsize=(12,8))
im = plt.imshow(inverted,'jet')
ax = plt.gca(); 
divider = make_axes_locatable(ax); cax = divider.append_axes("right", size="5%", pad=0.05); plt.colorbar(im, cax=cax, label='km/s'); plt.pause
# Out:
# <function matplotlib.pyplot.pause(interval)>

# %%
rows = 1
columns = 4
fig1 = plt.figure(figsize=(12,9))

ax = fig1.add_subplot(rows,columns,1)

x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(mean[:,25],x, linewidth=2.5)
plt.plot(mat[:,25]/1000,x, linewidth=2.5)
#plt.plot(p1[:,25],x, linewidth=2.5)
#plt.plot(q1[:,25],x, linewidth=2.5)
#plt.fill_between(x,np.expand_dims(p1[:,25],1),np.expand_dims(q1[:25],1))
pp = p1[:,25]/1000
qq = q1[:,25]/1000
plt.fill_betweenx(x,pp,qq)
plt.tight_layout()
plt.xlabel('vp(km/s), x=75')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()
#ax.set_ylim(ymin=0)

ax = fig1.add_subplot(rows,columns,2)

#x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(mean[:,80],x, linewidth=2.5)
plt.plot(mat[:,80]/1000,x, linewidth=2.5)
#plt.plot(p1[:,80],x, linewidth=2.5)
#plt.plot(q1[:,80],x, linewidth=2.5)
pp = p1[:,80]
qq = q1[:,80]
plt.fill_betweenx(x,pp,qq,alpha=0.4)
plt.tight_layout()
plt.xlabel('vp(km/s), x=100')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()

ax = fig1.add_subplot(rows,columns,3)

#x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(mean[:,120],x, linewidth=2.5)
plt.plot(mat[:,120]/1000,x, linewidth=2.5)
pp = p1[:,120]
qq = q1[:,120]
plt.fill_betweenx(x,pp,qq,alpha=0.4)
plt.tight_layout()
plt.xlabel('vp(km/s), x=250')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()

ax = fig1.add_subplot(rows,columns,4)

#x = np.linspace(0,nz*dx/1000,151)
#plt.figure(figsize=(4,10))
plt.plot(mean[:,150],x, linewidth=2.5)
plt.plot(mat[:,150]/1000,x, linewidth=2.5)
pp = p1[:,150]
qq = q1[:,150]
plt.fill_betweenx(x,pp,qq,alpha=0.4)
plt.tight_layout()
plt.xlabel('vp(km/s), x=250')
plt.ylabel('depth(m)')
ax = plt.gca(); ax.invert_yaxis()

# %%
pp = p1[:,25]
qq = q1[:,25]
plt.fill_betweenx(x,pp,qq)

# %%
rows = 5
columns = 3
fig1 = plt.figure(figsize=(15,12))

ax = fig1.add_subplot(rows,columns,1)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Down3IntAD0ep20.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet',aspect=0.15)
old = im1
plt.colorbar()
ax.set_title("Iteration 20")

ax = fig1.add_subplot(rows,columns,4)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Down3IntAD0ep100.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet',aspect=0.15)
new = im1
plt.colorbar()
ax.set_title("Iteration 100")

ax = fig1.add_subplot(rows,columns,7)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Down3IntAD0ep500.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet',aspect=0.15)
new = im1
plt.colorbar()
ax.set_title("Iteration 500")

ax = fig1.add_subplot(rows,columns,10)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Down3IntAD0ep1000.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet',aspect=0.15)
new = im1
plt.colorbar()
ax.set_title("Iteration 1000")

ax = fig1.add_subplot(rows,columns,13)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Down3IntAD0ep2000.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet',aspect=0.15)
new = im1
plt.colorbar()
ax.set_title("Iteration 2000")

fig1.tight_layout(pad=2.0)

#im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up2IntAD0ep60.npy')
#im1 = np.squeeze(im1)
#im1 = im1[20,:,:]
#im = plt.imshow(im1,'jet')
#ax = plt.gca();

# %%
rows = 5
columns = 3
fig1 = plt.figure(figsize=(15,12))

ax = fig1.add_subplot(rows,columns,1)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up2IntAD0ep20.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet')
old = im1
plt.colorbar()
ax.set_title("Iteration 20")

ax = fig1.add_subplot(rows,columns,4)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up2IntAD0ep100.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 100")

ax = fig1.add_subplot(rows,columns,7)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up2IntAD0ep500.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 500")

ax = fig1.add_subplot(rows,columns,10)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up2IntAD0ep1000.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 1000")

ax = fig1.add_subplot(rows,columns,13)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up2IntAD0ep2000.npy')
im1 = np.squeeze(im1)
im1 = im1[20,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 2000")
#ax = plt.gca(); 
#ax.set_title("iteration 10")
fig1.tight_layout(pad=2.0)

# %%
rows = 5
columns = 3
fig1 = plt.figure(figsize=(15,12))

ax = fig1.add_subplot(rows,columns,1)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up1IntAD0ep20.npy')
im1 = np.squeeze(im1)
im1 = im1[8,:,:]
im = plt.imshow(im1,'jet')
old = im1
plt.colorbar()
ax.set_title("Iteration 20")

ax = fig1.add_subplot(rows,columns,4)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up1IntAD0ep100.npy')
im1 = np.squeeze(im1)
im1 = im1[8,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 100")

ax = fig1.add_subplot(rows,columns,7)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up1IntAD0ep500.npy')
im1 = np.squeeze(im1)
im1 = im1[8,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 500")

ax = fig1.add_subplot(rows,columns,10)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up1IntAD0ep1000.npy')
im1 = np.squeeze(im1)
im1 = im1[8,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 1000")

ax = fig1.add_subplot(rows,columns,13)
im1 = np.load('/disk/student/adhara/Fall2021/PhysicsBasedFWI/marmousi21/Up1IntAD0ep2000.npy')
im1 = np.squeeze(im1)
im1 = im1[8,:,:]
im = plt.imshow(im1,'jet')
new = im1
plt.colorbar()
ax.set_title("Iteration 2000")
fig1.tight_layout(pad=2.0)

# %%
import numpy as np
from skimage.measure import block_reduce
import skimage
import scipy.io
import os
from IPython.core.debugger import set_trace

# %%
SimulateData  = True          # If False denotes training the CNN with SEGSaltData
ReUse         = False         # If False always re-train a network 
DataDim       = [2000,301]    # Dimension of original one-shot seismic data
data_dsp_blk  = (5,1)         # Downsampling ratio of input
ModelDim      = [201,301]     # Dimension of one velocity model
label_dsp_blk = (1,1)         # Downsampling ratio of output
dh            = 10            # Space interval

# %%
Epochs        = 1       # Number of epoch
TrainSize     = 50     # Number of training set
TestSize      = 10      # Number of testing set
TestBatchSize = 1

# %%
BatchSize         = 10      # Number of batch size
LearnRate         = 1e-3      # Learning rate
Nclasses          = 1         # Number of output channels
Inchannels        = 15        # Number of input channels, i.e. the number of shots
SaveEpoch         = 20        
DisplayStep       = 2         # Number of steps till outputting stats

# %%
tagD0 = 'georec'
tagV0 = 'vmodel'
tagD1 = 'Rec'
tagV1 = 'vmodel'
datafilename  = tagD0
dataname      = tagD1
truthfilename = tagV0
truthname     = tagV1
main_dir   = '/glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/'
data_dir    = main_dir + 'data/' 
train_data_dir  = data_dir  + 'train_data/'        # Replace your training data path here
test_data_dir   = data_dir  + 'test_data/'         # Replace your testing data path here
# Define directory for simulate data and SEG data respectively
if SimulateData:
    train_data_dir  = train_data_dir + 'SimulateData/'
    test_data_dir   = test_data_dir  + 'SimulateData/'
else:
    train_data_dir  = train_data_dir + 'SEGSaltData/'
    test_data_dir   = test_data_dir  + 'SEGSaltData/'

## Create Results and Models path
if os.path.exists('./results/') and os.path.exists('./models/'):
    results_dir     = main_dir + 'results/' 
    models_dir      = main_dir + 'models/'
else:
    os.makedirs('./results/')
    os.makedirs('./models/')
    results_dir     = main_dir + 'results/'
    models_dir      = main_dir + 'models/'
if SimulateData:
    results_dir     = results_dir + 'SimulateResults/'
    models_dir      = models_dir  + 'SimulataModel/'
else:
    results_dir     = results_dir + 'SEGSaltResults/'
    models_dir      = models_dir  + 'SEGSaltModel/'
if os.path.exists(results_dir) and os.path.exists(models_dir):  
    results_dir     = results_dir
    models_dir      = models_dir 
else:
    os.makedirs(results_dir)
    os.makedirs(models_dir)
    results_dir     = results_dir
    models_dir      = models_dir
# Create Model name
if SimulateData:
    tagM = 'Simulate'
else:
    tagM = 'SEGSalt'
tagM0 = '_FCNVMBModel'
tagM1 = '_TrainSize' + str(TrainSize)
tagM2 = '_Epoch'     + str(Epochs)
tagM3 = '_BatchSize' + str(BatchSize)
tagM4 = '_LR'        + str(LearnRate)

modelname = tagM+tagM0+tagM1+tagM2+tagM3+tagM4
# Change here to set the model as the pre-trained initialization
premodelname = 'Simulate_FCNVMBModel_TrainSize1600_Epoch100_BatchSize10_LR0.001'

# %%
# downsampling function by taking the middle value
def decimate(a,axis):
    idx = np.round((np.array(a.shape)[np.array(axis).reshape(1,-1)]+1.0)/2.0-1).reshape(-1)
    downa = np.array(a)[:,:,idx[0].astype(int),idx[1].astype(int)]
    return downa

# %%
os.system('rm -rf /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainA')
os.system('rm -rf /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainB')

os.system('mkdir /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainA')
os.system('mkdir /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainB')
# Out:
# 0

# %%
start = 1
train_size = TrainSize
in_channels = Inchannels
model_dim = ModelDim

for i in range(start,start+train_size):
        
    filename_seis = train_data_dir+'georec_train/'+datafilename+str(i)
    print(filename_seis)
        # Load .mat data
    data1_set = scipy.io.loadmat(filename_seis)
        #data1_set = np.float32(data1_set[str(dataname)].reshape([data_dim[0],data_dim[1],in_channels]))
    data1_set = np.float32(data1_set[str(dataname)])
        # Change the dimention [h, w, c] --> [c, h, w]
    for k in range (0,in_channels):
        data11_set     = np.float32(data1_set[:,:,k])
        data11_set     = np.float32(data11_set)
        # Data downsampling
        # note that the len(data11_set.shape)=len(block_size.shape)=2
        #data11_set     = block_reduce(data11_set,block_size=data_dsp_blk,func=decimate)
        #data11_set     = data11_set[1:2000:5,:]
        data11_set     = np.expand_dims(data11_set,axis=0)
        data_dsp_dim   = data11_set.shape
        #data11_set     = data11_set.reshape(1,data_dsp_dim[0]*data_dsp_dim[1])
        if k==0:
            train1_set = data11_set
        else:
            train1_set = np.append(train1_set,data11_set,axis=0)
    filename_label     = train_data_dir+'vmodel_train/'+truthfilename+str(i)
    data2_set          = scipy.io.loadmat(filename_label)
    data2_set          = np.float32(data2_set[str(truthname)].reshape(model_dim))
        # Label downsampling
    data2_set          = block_reduce(data2_set,block_size=label_dsp_blk,func=np.max)
    label_dsp_dim      = data2_set.shape
    #data2_set          = data2_set.reshape(1,label_dsp_dim[0]*label_dsp_dim[1])
    data2_set          = np.float32(data2_set)
    #if i==start:
    #    train_set      = train1_set
    #    label_set      = data2_set
    #else:
    #    train_set      = np.append(train_set,train1_set,axis=0)
    #    label_set      = np.append(label_set,data2_set,axis=0)
        
    A = train1_set
    B = data2_set
    file = open('/glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainA/'+str(i)+'.npy','wb')
    np.save(file,A)
    file.close()
    file = open('/glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainB/'+str(i)+'.npy','wb')
    np.save(file,B)
    file.close()
            
#train_set = train_set.reshape((train_size,in_channels,data_dsp_dim[0]*data_dsp_dim[1]))
#label_set = label_set.reshape((train_size,1,label_dsp_dim[0]*label_dsp_dim[1]))
# Out:
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec1
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec2
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec3
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec4
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec5
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec6
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec7
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec8
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec9
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec10
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec11
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec12
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec13
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec14
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec15
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec16
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec17
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec18
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec19
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec20
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec21
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec22
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec23
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec24
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec25
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec26
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec27
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec28
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec29
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec30
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec31
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec32
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec33
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec34
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec35
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec36
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec37
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec38
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec39
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec40
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec41
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec42
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec43
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec44
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec45
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec46
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec47
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec48
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec49
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/train_data/SimulateData/georec_train/georec50

# %%
po = np.load('/glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/trainB/1.npy')
np.shape(po)
# Out:
# (201, 301)

# %%
type(label_dsp_dim)
# Out:
# tuple

# %%
tt = (201,301)

# %%
type(tt)
# Out:
# tuple

# %%
os.system('rm -rf /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/testA')
os.system('rm -rf /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/testB')

os.system('mkdir /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/testA')
os.system('mkdir /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/testB')
# Out:
# 0

# %%
start = 1601
test_size = TestSize
in_channels = Inchannels
model_dim = ModelDim
kk = 0
for i in range(start,start+test_size):
    kk = kk + 1
    filename_seis = test_data_dir+'georec_test/'+datafilename+str(i)
    print(filename_seis)
        # Load .mat data
    data1_set = scipy.io.loadmat(filename_seis)
        #data1_set = np.float32(data1_set[str(dataname)].reshape([data_dim[0],data_dim[1],in_channels]))
    data1_set = np.float32(data1_set[str(dataname)])
        # Change the dimention [h, w, c] --> [c, h, w]
    for k in range (0,in_channels):
        data11_set     = np.float32(data1_set[:,:,k])
        data11_set     = np.float32(data11_set)
        # Data downsampling
        # note that the len(data11_set.shape)=len(block_size.shape)=2
        #data11_set     = block_reduce(data11_set,block_size=data_dsp_blk,func=decimate)
        #data11_set     = data11_set[1:2000:5,:]
        data11_set     = np.expand_dims(data11_set,axis=0)
        data_dsp_dim   = data11_set.shape
        #data11_set     = data11_set.reshape(1,data_dsp_dim[0]*data_dsp_dim[1])
        if k==0:
            train1_set = data11_set
        else:
            train1_set = np.append(train1_set,data11_set,axis=0)
    filename_label     = test_data_dir+'vmodel_test/'+truthfilename+str(i)
    data2_set          = scipy.io.loadmat(filename_label)
    data2_set          = np.float32(data2_set[str(truthname)].reshape(model_dim))
        # Label downsampling
    data2_set          = block_reduce(data2_set,block_size=label_dsp_blk,func=np.max)
    label_dsp_dim      = data2_set.shape
    #data2_set          = data2_set.reshape(1,label_dsp_dim[0]*label_dsp_dim[1])
    data2_set          = np.float32(data2_set)
    #if i==start:
    #    train_set      = train1_set
    #    label_set      = data2_set
    #else:
    #    train_set      = np.append(train_set,train1_set,axis=0)
    #    label_set      = np.append(label_set,data2_set,axis=0)
        
    A = train1_set
    B = data2_set
    file = open('/glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/testA/'+str(kk)+'.npy','wb')
    np.save(file,A)
    file.close()
    file = open('/glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/testB/'+str(kk)+'.npy','wb')
    np.save(file,B)
    file.close()
            
#train_set = train_set.reshape((train_size,in_channels,data_dsp_dim[0]*data_dsp_dim[1]))
#label_set = label_set.reshape((train_size,1,label_dsp_dim[0]*label_dsp_dim[1]))
# Out:
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1601
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1602
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1603
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1604
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1605
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1606
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1607
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1608
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1609
# /glb/data/eptr_am_2/Arnab/FCNVMB-Deep-learning-based-seismic-velocity-model-building/data/test_data/SimulateData/georec_test/georec1610

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable, axes_size
# Define a plot function to plot two slices. Made some modifications to fit a colorbar to it.
def plot_two_slices(data1,data2,title1='',title2=''):
    aspect = 20
    pad_fraction = 0.5
    
    #gs = plt.GridSpec(1, 1)
    fig,ax = plt.subplots(1,2, figsize = (20,40));

    # Plot the first section
    im1 = ax[0].imshow(np.squeeze(data1))

    ax[0].set(title=title1)
    divider = make_axes_locatable(ax[0])
    width = axes_size.AxesY(ax[0], aspect=1./aspect)
    pad = axes_size.Fraction(pad_fraction, width)
    cax = divider.append_axes("right", size=width, pad=pad)
    plt.colorbar(im1, cax=cax)
    
    #Plot the second section
    im2 = ax[1].imshow(np.squeeze(data2))

    ax[1].set(title=title2)
    divider = make_axes_locatable(ax[1])
    width = axes_size.AxesY(ax[1], aspect=1./aspect)
    pad = axes_size.Fraction(pad_fraction, width)
    cax = divider.append_axes("right", size=width, pad=pad)
    plt.colorbar(im2, cax=cax)
    
    plt.subplots_adjust(wspace = 0.2)
    #plt.colorbar(im, ax=ax)
    plt.show()

# %%
real = np.load('/glb/data/eptr_am_2/Arnab/volumes/training_data/events/HorizonWindow/att_volumes/slices/finalTest/Output1/25_real_BT.npy')
fake = np.load('/glb/data/eptr_am_2/Arnab/volumes/training_data/events/HorizonWindow/att_volumes/slices/finalTest/Output1/25_fake_BT.npy')
real = real*(4500-2000)+2000
fake = fake*(4500-2000)+2000
plot_two_slices(real,fake,title1='real',title2='fake')

# %%
po1 = np.load('/glb/hou/pt.sgs/data/ml_ai_us/4d/usadh7/github_repos/FCNVMB-Deep-learning-based-seismic-velocity-model-building/ftout1.npy')
po2 = np.load('/glb/hou/pt.sgs/data/ml_ai_us/4d/usadh7/github_repos/FCNVMB-Deep-learning-based-seismic-velocity-model-building/ftout2.npy')

# %%
plot_two_slices(po1,po2,title1='t1',title2='t2')

# %%
plt.imshow(po1-po2)
